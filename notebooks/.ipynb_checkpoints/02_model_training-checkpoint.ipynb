# %%
import pandas as pd
import nltk
from nltk.probability import *
from itertools import chain

# %%
base_path = "../notebooks/tokenized_data/"

train_data = pd.read_excel(f"{base_path}tokenized_test_data.xlsx")
test_data  = pd.read_excel(f"{base_path}tokenized_test_data.xlsx")

# %%
train_data.head()
# Out:
#    Unnamed: 0          ID  Label  \
# 0           0  11972.json      1
# 1           1  11685.json      0
# 2           2  11096.json      0
# 3           3   5209.json      1
# 4           4   9524.json      0
#
#                                            Statement  \
# 0              building wall mexico border literally
# 1                      wisconsin pace double layoffs
# 2                                   john mccain vets
# 3  suzanne bonamici supports plan cut choice medi...
# 4  reporter center criminal scheme violate campai...
#
#                                              Subject  \
# 0                                        immigration
# 1                                               jobs
# 2                    military,veterans,voting-record
# 3  medicare,message-machine-2012,campaign-adverti...
# 4  campaign-finance,legal-issues,campaign-adverti...
#
#                             Speaker                 Title      State  \
# 0                        rick-perry              governor      texas
# 1                 katrina-shankland  state representative  wisconsin
# 2                      donald-trump       president-elect   new york
# 3                     rob-cornilles            consultant     oregon
# 4  state-democratic-party-wisconsin                   NaN  wisconsin
#
#         Party  True Counts  Flase Counts  Half True Counts  \
# 0  republican           30            30                42
# 1    democrat            2             1                 0
# 2  republican           63           114                51
# 3  republican            1             1                 3
# 4    democrat            5             7                 2
#
#    Mostly True Counts  Pants On Fire Counts                       Context
# 0                  23                    18               radio interview
# 1                   0                     0             a news conference
# 2                  37                    61  comments on abc's this week.
# 3                   1                     1                  a radio show
# 4                   2                     7                   a web video

# %%
train_data.drop('Unnamed: 0', axis=1, inplace=True)
test_data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
train_data.head()
# Out:
#            ID  Label                                          Statement  \
# 0  11972.json      1              building wall mexico border literally
# 1  11685.json      0                      wisconsin pace double layoffs
# 2  11096.json      0                                   john mccain vets
# 3   5209.json      1  suzanne bonamici supports plan cut choice medi...
# 4   9524.json      0  reporter center criminal scheme violate campai...
#
#                                              Subject  \
# 0                                        immigration
# 1                                               jobs
# 2                    military,veterans,voting-record
# 3  medicare,message-machine-2012,campaign-adverti...
# 4  campaign-finance,legal-issues,campaign-adverti...
#
#                             Speaker                 Title      State  \
# 0                        rick-perry              governor      texas
# 1                 katrina-shankland  state representative  wisconsin
# 2                      donald-trump       president-elect   new york
# 3                     rob-cornilles            consultant     oregon
# 4  state-democratic-party-wisconsin                   NaN  wisconsin
#
#         Party  True Counts  Flase Counts  Half True Counts  \
# 0  republican           30            30                42
# 1    democrat            2             1                 0
# 2  republican           63           114                51
# 3  republican            1             1                 3
# 4    democrat            5             7                 2
#
#    Mostly True Counts  Pants On Fire Counts                       Context
# 0                  23                    18               radio interview
# 1                   0                     0             a news conference
# 2                  37                    61  comments on abc's this week.
# 3                   1                     1                  a radio show
# 4                   2                     7                   a web video

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
