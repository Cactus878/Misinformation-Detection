# %%
import pandas as pd
import nltk
from nltk.probability import *
from itertools import chain

# %%
# Path for liar data
base_path = "../data/liar/"

# Load the liar files
train_df = pd.read_csv(f"{base_path}train.tsv", sep="\t", header=None)
val_df   = pd.read_csv(f"{base_path}valid.tsv", sep="\t", header=None)
test_df  = pd.read_csv(f"{base_path}test.tsv", sep="\t", header=None)

# %%
# Rename columns
train_df = train_df.rename(columns={0: "ID", 1: "Label", 2: "Statement", 3: "Subject", 4: "Speaker", 5: "Title", 6: "State", 7: "Party", 8: "True Counts", 9: "Flase Counts", 10: "Half True Counts", 11: "Mostly True Counts", 12: "Pants On Fire Counts", 13: "Context"})
val_df = val_df.rename(columns={0: "ID", 1: "Label", 2: "Statement", 3: "Subject", 4: "Speaker", 5: "Title", 6: "State", 7: "Party", 8: "True Counts", 9: "Flase Counts", 10: "Half True Counts", 11: "Mostly True Counts", 12: "Pants On Fire Counts", 13: "Context"})
test_df = test_df.rename(columns={0: "ID", 1: "Label", 2: "Statement", 3: "Subject", 4: "Speaker", 5: "Title", 6: "State", 7: "Party", 8: "True Counts", 9: "Flase Counts", 10: "Half True Counts", 11: "Mostly True Counts", 12: "Pants On Fire Counts", 13: "Context"})

# %%
print("train data shape:", train_df.shape)
print("validate data shape:", val_df.shape)
print("testing data shape:", test_df.shape)
# Out:
# train data shape: (10240, 14)
# validate data shape: (1284, 14)
# testing data shape: (1267, 14)

# %%
train_df.head()
# Out:
#            ID        Label                                          Statement  \
# 0   2635.json        false  Says the Annies List political group supports ...
# 1  10540.json    half-true  When did the decline of coal start? It started...
# 2    324.json  mostly-true  Hillary Clinton agrees with John McCain "by vo...
# 3   1123.json        false  Health care reform legislation is likely to ma...
# 4   9028.json    half-true  The economic turnaround started at the end of ...
#
#                               Subject         Speaker                 Title  \
# 0                            abortion    dwayne-bohac  State representative
# 1  energy,history,job-accomplishments  scott-surovell        State delegate
# 2                      foreign-policy    barack-obama             President
# 3                         health-care    blog-posting                   NaN
# 4                        economy,jobs   charlie-crist                   NaN
#
#       State       Party  True Counts  Flase Counts  Half True Counts  \
# 0     Texas  republican          0.0           1.0               0.0
# 1  Virginia    democrat          0.0           0.0               1.0
# 2  Illinois    democrat         70.0          71.0             160.0
# 3       NaN        none          7.0          19.0               3.0
# 4   Florida    democrat         15.0           9.0              20.0
#
#    Mostly True Counts  Pants On Fire Counts              Context
# 0                 0.0                   0.0             a mailer
# 1                 1.0                   0.0      a floor speech.
# 2               163.0                   9.0               Denver
# 3                 5.0                  44.0       a news release
# 4                19.0                   2.0  an interview on CNN

# %%
val_df.head()
# Out:
#            ID        Label                                          Statement  \
# 0  12134.json  barely-true  We have less Americans working now than in the...
# 1    238.json   pants-fire  When Obama was sworn into office, he DID NOT u...
# 2   7891.json        false  Says Having organizations parading as being so...
# 3   8169.json    half-true     Says nearly half of Oregons children are poor.
# 4    929.json    half-true  On attacks by Republicans that various program...
#
#                             Subject          Speaker  \
# 0                      economy,jobs   vicky-hartzler
# 1  obama-birth-certificate,religion      chain-email
# 2   campaign-finance,congress,taxes  earl-blumenauer
# 3                           poverty  jim-francesconi
# 4                  economy,stimulus     barack-obama
#
#                                            Title     State       Party  \
# 0                            U.S. Representative  Missouri  republican
# 1                                            NaN       NaN        none
# 2                            U.S. representative    Oregon    democrat
# 3  Member of the State Board of Higher Education    Oregon        none
# 4                                      President  Illinois    democrat
#
#    True Counts  Flase Counts  Half True Counts  Mostly True Counts  \
# 0            1             0                 1                   0
# 1           11            43                 8                   5
# 2            0             1                 1                   1
# 3            0             1                 1                   1
# 4           70            71               160                 163
#
#    Pants On Fire Counts                        Context
# 0                     0   an interview with ABC17 News
# 1                   105                            NaN
# 2                     0  a U.S. Ways and Means hearing
# 3                     0             an opinion article
# 4                     9        interview with CBS News

# %%
test_df.head()
# Out:
#            ID       Label                                          Statement  \
# 0  11972.json        true  Building a wall on the U.S.-Mexico border will...
# 1  11685.json       false  Wisconsin is on pace to double the number of l...
# 2  11096.json       false  Says John McCain has done nothing to help the ...
# 3   5209.json   half-true  Suzanne Bonamici supports a plan that will cut...
# 4   9524.json  pants-fire  When asked by a reporter whether hes at the ce...
#
#                                              Subject  \
# 0                                        immigration
# 1                                               jobs
# 2                    military,veterans,voting-record
# 3  medicare,message-machine-2012,campaign-adverti...
# 4  campaign-finance,legal-issues,campaign-adverti...
#
#                             Speaker                 Title      State  \
# 0                        rick-perry              Governor      Texas
# 1                 katrina-shankland  State representative  Wisconsin
# 2                      donald-trump       President-Elect   New York
# 3                     rob-cornilles            consultant     Oregon
# 4  state-democratic-party-wisconsin                   NaN  Wisconsin
#
#         Party  True Counts  Flase Counts  Half True Counts  \
# 0  republican           30            30                42
# 1    democrat            2             1                 0
# 2  republican           63           114                51
# 3  republican            1             1                 3
# 4    democrat            5             7                 2
#
#    Mostly True Counts  Pants On Fire Counts                       Context
# 0                  23                    18               Radio interview
# 1                   0                     0             a news conference
# 2                  37                    61  comments on ABC's This Week.
# 3                   1                     1                  a radio show
# 4                   2                     7                   a web video

# %%
# Combine test and val for simplicity
df = pd.concat([train_df, val_df, test_df], ignore_index=True)

# %%
df['Party'].value_counts()
# Out:
# Party
# republican                      5665
# democrat                        4137
# none                            2181
# organization                     264
# independent                      180
# newsmaker                         64
# libertarian                       51
# journalist                        49
# activist                          45
# columnist                         44
# talk-show-host                    32
# state-official                    24
# labor-leader                      15
# business-leader                   11
# tea-party-member                  10
# education-official                 3
# green                              3
# constitution-party                 3
# government-body                    2
# county-commissioner                2
# liberal-party-canada               1
# Moderate                           1
# democratic-farmer-labor            1
# ocean-state-tea-party-action       1
# Name: count, dtype: int64

# %%
print("train data shape:", df.shape)
# Out:
# train data shape: (12791, 14)

# %%
def lowerStringCols(df):
    for col in df.columns:
        if df[col].dtype == "O": # If column data type is an object
            df[col] = df[col].str.lower()
    return df

# %%
df = lowerStringCols(df)

# %%
# Extract information about the review.
df_statement_data = df['Statement']

# %%
# Tokenize each clothing review. 
def tokenize(review):
    pattern = r"[a-zA-Z]+(?:[-'][a-zA-Z]+)?"
    tokenizer = nltk.RegexpTokenizer(pattern) 
    tokenized_review = tokenizer.tokenize(review)
    return tokenized_review

# %%
# Create token lists
tokenized_df_statement_data = [tokenize(statement) for statement in df_statement_data]

# %%
# Remove words with a length less than 2
def removeWordsWithLessThanTwoChar(statement_list):
    
    statement_list = [
        [token for token in sublist if len(token) > 1]
        for sublist in statement_list
    ]
    
    return statement_list

# %%
tokenized_df_statement_data = removeWordsWithLessThanTwoChar(tokenized_df_statement_data)

# %%
# Create stop words list
stop_words = []

with open("stopwords-en.txt", "r", encoding="utf-8") as file:
    for word in file:
        # Remove /n from the word
        word = word.strip()
        
        stop_words.append(word)

# %%
# Remove stop words from statement lists
def removeStopWords(statement_list):
    
    statement_list = [
        [token for token in sublist if token not in stop_words]
        for sublist in statement_list
    ]
    
    return statement_list

# %%
tokenized_df_statement_data = removeStopWords(tokenized_df_statement_data)

# %%
tokenized_df_statement_data
# Out:
# [['annies',
#   'list',
#   'political',
#   'supports',
#   'third-trimester',
#   'abortions',
#   'demand'],
#  ['decline',
#   'coal',
#   'start',
#   'started',
#   'natural',
#   'gas',
#   'started',
#   'president',
#   'george',
#   'bushs',
#   'administration'],
#  ['hillary',
#   'clinton',
#   'agrees',
#   'john',
#   'mccain',
#   'voting',
#   'george',
#   'bush',
#   'benefit',
#   'doubt',
#   'iran'],
#  ['health',
#   'care',
#   'reform',
#   'legislation',
#   'mandate',
#   'sex',
#   'change',
#   'surgeries'],
#  ['economic', 'turnaround', 'started', 'term'],
#  ['chicago',
#   'bears',
#   'starting',
#   'quarterbacks',
#   'total',
#   'tenured',
#   'uw',
#   'faculty',
#   'fired',
#   'decades'],
#  ['jim', 'dunnam', 'lived', 'district', 'represents'],
#  ['person',
#   'stage',
#   'actively',
#   'passing',
#   'russ',
#   'feingold',
#   'toughest',
#   'ethics',
#   'reform',
#   'watergate'],
#  ['oregon',
#   'lottery',
#   'funds',
#   'port',
#   'newport',
#   'eventually',
#   'land',
#   'noaa',
#   'marine',
#   'operations',
#   'center-pacific'],
#  ['gop',
#   'primary',
#   'opponents',
#   'glenn',
#   'grothman',
#   'joe',
#   'leibham',
#   'cast',
#   'compromise',
#   'vote',
#   'cost',
#   'electricity',
#   'costs'],
#  ['time',
#   'history',
#   'share',
#   'national',
#   'popular',
#   'vote',
#   'margin',
#   'latino',
#   'vote',
#   'margin'],
#  ['americans', 'slipped', 'middle', 'class', 'poverty'],
#  ['mitt',
#   'romney',
#   'governor',
#   'massachusetts',
#   'slow',
#   'rate',
#   'growth',
#   'government',
#   'cut'],
#  ['economy', 'bled', 'government', 'shutdown'],
#  ['affordable', 'care', 'sense', 'waived', 'suspended'],
#  ['election',
#   'november',
#   'percent',
#   'american',
#   'people',
#   'chose',
#   'vote',
#   'percent',
#   'people',
#   'percent',
#   'low-income',
#   'workers',
#   'chose',
#   'vote'],
#  ['mccain',
#   'opposed',
#   'requirement',
#   'government',
#   'american-made',
#   'motorcycles',
#   'buy-american',
#   'provisions',
#   'quote',
#   'disgraceful'],
#  ['rep',
#   'ron',
#   'd-wis',
#   'fellow',
#   'democrats',
#   'spending',
#   'spree',
#   'credit',
#   'card',
#   'maxed'],
#  ['water',
#   'rates',
#   'manila',
#   'philippines',
#   'raised',
#   'percent',
#   'subsidiary',
#   'bank',
#   'partial',
#   'owner'],
#  ['people', 'left', 'puerto', 'rico'],
#  ['women', 'adjust', 'inflation', 'john', 'kitzhaber', 'elected', 'governor'],
#  ['united', 'corporate', 'tax', 'rate'],
#  ['auto', 'industry', 'america', 'history'],
#  ['scott',
#   'walker',
#   'favors',
#   'cutting',
#   'families',
#   'children',
#   'health',
#   'care'],
#  ['mitt', 'romney', 'rid', 'planned', 'parenthood'],
#  ['jonathan', 'gruber'],
#  ['hate',
#   'crimes',
#   'american',
#   'muslims',
#   'mosques',
#   'tripled',
#   'paris',
#   'san',
#   'bernardino'],
#  ['rick',
#   'perry',
#   'lost',
#   'election',
#   'remains',
#   'person',
#   'texas',
#   'governorship',
#   'times',
#   'landslide',
#   'elections'],
#  ['isis', 'supporter', 'tweeted', 'shooting', 'chattanooga', 'tenn'],
#  ['youth', 'unemployment', 'minority', 'communities', 'percent'],
#  ['paul', 'ryan', 'endorsing', 'trump'],
#  ['constantly', 'budget', 'deficits', 'business', 'climates'],
#  ['obama',
#   'administration',
#   'months',
#   'burn',
#   'coal',
#   'limitedly',
#   'existing',
#   'plants'],
#  ['cut',
#   'business',
#   'taxes',
#   'percent',
#   'businesses',
#   'pay',
#   'business',
#   'tax'],
#  ['mark', 'pryor', 'votes', 'obama', 'percent', 'time'],
#  ['federal', 'government', 'authority', 'regulate', 'toilet', 'seats'],
#  ['austin', 'city', 'basically', 'doubled', 'size', 'founded'],
#  ['nuclear',
#   'conducted',
#   'nation',
#   'time',
#   "earth's",
#   'nuclear',
#   'permanent',
#   'security',
#   'council',
#   'conducted',
#   'percent',
#   'total',
#   'nuclear',
#   'tests'],
#  ['catastrophic',
#   'event',
#   'atlanta-area',
#   'offices',
#   'centers',
#   'disease',
#   'control',
#   'prevention',
#   'self-destruct'],
#  ['president', 'george', 'bush', 'debt', 'president', 'obama', 'debt'],
#  ['supreme',
#   'court',
#   'justice',
#   'suggested',
#   'decided',
#   'based',
#   'south',
#   'african',
#   'law'],
#  ['marco',
#   'rubio',
#   'skipped',
#   'defense',
#   'votes',
#   'including',
#   'arm',
#   'kurds',
#   'fight',
#   'isis'],
#  ['rep',
#   'david',
#   'cicilline',
#   'responsible',
#   'federal',
#   'loan',
#   'guarantee',
#   'solyndra',
#   'failed',
#   'solar',
#   'company'],
#  ['ohio',
#   'budget',
#   'item',
#   'signed',
#   'law',
#   'john',
#   'kasich',
#   'requires',
#   'women',
#   'seeking',
#   'abortion',
#   'undergo',
#   'mandatory',
#   'vaginal',
#   'probe'],
#  ['director',
#   'homeland',
#   'security',
#   'term',
#   'terrorist',
#   'attack',
#   'substitutes',
#   'man-made',
#   'disaster'],
#  ['african-american',
#   'youth',
#   'unemployment',
#   'percent',
#   'hispanic',
#   'youth',
#   'unemployment',
#   'percent'],
#  ['obamacare', 'provide', 'insurance', 'non-u', 'residents', 'illegally'],
#  ['president',
#   'barack',
#   'obama',
#   'deficit',
#   'reduction',
#   'commissions',
#   'ideas'],
#  ['barack',
#   'obama',
#   'hillary',
#   'clinton',
#   'changed',
#   'rules',
#   'engagement',
#   'cost',
#   'capt',
#   'humayun',
#   'khans',
#   'life'],
#  ['hillary',
#   'clinton',
#   'co-sponsored',
#   'legislation',
#   'jail',
#   'flag',
#   'burners'],
#  ['paperback',
#   'edition',
#   'mitt',
#   'romneys',
#   'book',
#   'deleted',
#   'massachusetts',
#   'individual',
#   'mandate',
#   'model',
#   'country'],
#  ['maggie', 'hassan', 'raised', 'tuition', 'america'],
#  ['terry',
#   'mcauliffe',
#   'person',
#   'invented',
#   'scheme',
#   'rent',
#   'lincoln',
#   'bedroom'],
#  ['created',
#   'jobs',
#   'cut',
#   'unemployment',
#   'rate',
#   'york',
#   'private',
#   'sector',
#   'jobs',
#   'history'],
#  ['towns', 'west', 'texas', 'water', 'truck', 'water'],
#  ['georgia', 'women', 'earn', 'cents', 'dollar', 'earned'],
#  ['federal',
#   'verifies',
#   'employees',
#   'authorized',
#   'inaccurate',
#   'percent',
#   'excess',
#   'percent',
#   'time'],
#  ['build', 'wall', 'environmental', 'impact', 'statements'],
#  ['sen', "obama's", 'campaign', 'announced', 'choosing', 'cabinet'],
#  ['percent', 'latinos', 'texas', 'registered', 'vote', 'percent'],
#  ['percent', 'public', 'schools', 'country', 'offer', 'classes'],
#  ['republican', 'candidate', 'government', 'economy'],
#  ['military',
#   'recruiters',
#   'harvard',
#   'elena',
#   'kagan',
#   'position',
#   'supreme',
#   'court',
#   'ruled',
#   'unanimously',
#   'wrong'],
#  ['public',
#   'school',
#   'teachers',
#   'texas',
#   'non-teachers',
#   'public',
#   'schools'],
#  ['mayor', 'cicilline', 'providence', 'sanctuary', 'city'],
#  ['transgender', 'individuals', 'chance', 'murdered'],
#  ['bain',
#   'capital',
#   'helped',
#   'start',
#   'childhood',
#   'learning',
#   'company',
#   'called',
#   'bright',
#   'horizons',
#   'lady',
#   'michelle',
#   'obama',
#   'rightly',
#   'praised'],
#  ['rushed',
#   'stage',
#   'dayton',
#   'ohio',
#   'chatter',
#   'isis',
#   'isis',
#   'social',
#   'media',
#   'posts'],
#  ['rep',
#   'phil',
#   'gingrey',
#   'government',
#   'power',
#   'electronically',
#   'spy',
#   'americans',
#   'warrant'],
#  ['alex',
#   'sink',
#   'funneled',
#   'quarters',
#   'dollars',
#   'no-bid',
#   'contracts',
#   'bank',
#   'america'],
#  ['population',
#   'growth',
#   'virginia',
#   'job',
#   'creation',
#   'bob',
#   'mcdonnell',
#   'governor'],
#  ['obama',
#   'values',
#   'florida',
#   'collapsed',
#   'construction',
#   'jobs',
#   'lost',
#   'foreclosure',
#   'rate'],
#  ['arizona',
#   'immigration',
#   'law',
#   'police',
#   'officer',
#   'appears',
#   'suspicious',
#   'undocumented',
#   'person'],
#  ['time', 'history', 'debt', 'war'],
#  ['cost',
#   'health',
#   'care',
#   'single-biggest',
#   'factor',
#   'driving',
#   'federal',
#   'budget',
#   'deficit'],
#  ['recession',
#   'consumer',
#   'native',
#   'perversity',
#   'begun',
#   'save',
#   'savings',
#   'rate',
#   'percent'],
#  ['supreme', 'court', 'nominee', 'forthcoming', 'confirmation', 'hearings'],
#  ['homeless', 'veteran'],
#  ['charlie', 'crist', 'supports', 'cuts', 'medicare', 'advantage', 'program'],
#  ['unacceptable',
#   'chinese',
#   'larger',
#   'wind',
#   'power',
#   'solar',
#   'panels',
#   'photovoltaic',
#   'manufacturing',
#   'europe',
#   'forget',
#   'united'],
#  ['scott',
#   'brown',
#   'co-sponsored',
#   'legislation',
#   'employers',
#   'deny',
#   'women',
#   'coverage',
#   'birth',
#   'control'],
#  ['lives', 'women', 'birth', 'control'],
#  ['egypt', 'strides', 'political', 'democratic', 'reform'],
#  ['attention',
#   'paid',
#   'week',
#   'chris',
#   'christie',
#   'coverage',
#   'benghazi',
#   'pale',
#   'significance'],
#  ['rep', 'steve', 'southerland', 'voted', 'shutdown'],
#  ['rick', 'perrys', 'texas', 'import', 'nurses', 'countries'],
#  ['federal', 'criminal', 'law', 'crime', 'transport', 'dentures', 'lines'],
#  ['built',
#   'prison',
#   'days',
#   'mass',
#   'incarceration',
#   'explosion',
#   'nonviolent',
#   'offenders'],
#  ['sen', "mccain's", 'tax', 'plan', 'virtually', 'middle', 'class'],
#  ['austin',
#   'burdened',
#   'fastest-growing',
#   'tax',
#   'increases',
#   'major',
#   'city',
#   'nation'],
#  ['phoenix', 'arizona', 'kidnapping', 'capital'],
#  ['belong', 'afl-cio'],
#  ['insurance', 'commissioner', 'squat', 'health', 'care'],
#  ['poll', 'republican', 'candidate', 'beat', 'barack', 'obama', 'texas'],
#  ['president',
#   'ronald',
#   'reagan',
#   'troops',
#   'conflict',
#   'circumstance',
#   'grenada',
#   'peacekeeping',
#   'setting',
#   'lebanon'],
#  ['david', 'jolly', 'supports', 'privatizing', 'social', 'security'],
#  ['population', 'growth', 'lowest', 'depression'],
#  ['average',
#   'student',
#   'florida',
#   'pay',
#   'pocket',
#   'major',
#   'universities',
#   'tuition',
#   'spend',
#   'cellphones'],
#  ['americans', 'died', 'gunfire', 'died', 'wars', 'countrys', 'history'],
#  ['foreclosure',
#   'tax',
#   'tax',
#   'facing',
#   'foreclosure',
#   'millions',
#   'families',
#   'modified',
#   'mortgage',
#   'short',
#   'sale',
#   'lender'],
#  ['florida',
#   'department',
#   'agricultures',
#   'freshfromflorida',
#   'permit',
#   'carry',
#   'loaded',
#   'hidden',
#   'gun',
#   'leaving',
#   'house'],
#  ['atlanta',
#   'streetcar',
#   'expected',
#   'create',
#   'jobs',
#   'construction',
#   'totaling',
#   'jobs'],
#  ['raising', 'minimum', 'wage', 'hour', 'lift', 'americans', 'poverty'],
#  ['secretary',
#   'john',
#   'kerry',
#   'senator',
#   'flew',
#   'managua',
#   'met',
#   'communist',
#   'dictator',
#   'daniel',
#   'ortega',
#   'accused',
#   'reagan',
#   'administration',
#   'engaging',
#   'terrorism'],
#  ['nato', 'major', 'terror', 'division', 'credit', 'criticism', 'nato'],
#  ['sen', 'obama', 'percent', 'prochoice', 'rating'],
#  ['gina',
#   'raimondo',
#   'office',
#   'investment',
#   'fees',
#   'pension',
#   'portfolio',
#   'annually'],
#  ['federal', 'debt', 'growing', 'day'],
#  ['president',
#   'barack',
#   'obamas',
#   'jobs',
#   'lay',
#   'teachers',
#   'firefighters',
#   'police',
#   'officers'],
#  ['teachers', 'teachers'],
#  ['two-thirds',
#   'wisconsinites',
#   'receiving',
#   'unemployment',
#   'checks',
#   'required',
#   'search',
#   'current',
#   'search',
#   'exemptions'],
#  ['president',
#   'obamas',
#   'health-care',
#   'reforms',
#   'premium',
#   'average',
#   'plan',
#   'family'],
#  ['irs', 'investigated', 'liberal', 'progressive', 'irs', 'basically'],
#  ['obama', 'promised', 'unemployment', 'percent'],
#  ['economy', 'creating', 'jobs', 'fastest', 'pace'],
#  ['president',
#   'obama',
#   'decided',
#   'meet',
#   'prime',
#   'minister',
#   'benjamin',
#   'netanyahu',
#   'york'],
#  ['majority', 'marry', 'freely', 'fired', 'love'],
#  ['oregon',
#   'reps',
#   'peter',
#   'defazio',
#   'earl',
#   'blumenauer',
#   'socialists',
#   'openly',
#   'serving',
#   'congress'],
#  ['rudy',
#   'giuliani',
#   'underqualified',
#   'george',
#   'bush',
#   'seek',
#   'presidency'],
#  ['presidents', 'governors', 'senators'],
#  ['britains',
#   'vote',
#   'leave',
#   'european',
#   'union',
#   'hours',
#   'americans',
#   'lost'],
#  ['medicaid', 'spending', 'declined', 'percent', 'decline'],
#  ['texas', 'constables', 'died', 'duty'],
#  ['rick', 'scott', 'cut', 'cost', 'prepaid', 'college', 'tuition'],
#  ['city',
#   'columbus',
#   'save',
#   'employees',
#   'contribute',
#   'guaranteed-check',
#   'pensions'],
#  ["florida's",
#   'cfo',
#   'shut',
#   "krakow's",
#   'scam',
#   'refunded',
#   'josephine',
#   'victims'],
#  ['women', 'sciences', 'degrees', 'factor'],
#  ['air', 'force', 'taxpayers', 'fund', 'fantasy', 'football', 'league'],
#  ['barack',
#   'hussein',
#   'obama',
#   'force',
#   'courts',
#   'accept',
#   'islamic',
#   'sharia',
#   'law',
#   'domestic',
#   'disputes'],
#  ['percent',
#   'murders',
#   'crimes',
#   'committed',
#   'guns',
#   'people',
#   'legally',
#   'purchase',
#   'guns'],
#  ['neighborhood', 'schools', 'closing'],
#  ['told',
#   'gay',
#   'organizers',
#   'massachusetts',
#   'stronger',
#   'advocate',
#   'special',
#   'rights',
#   'ted',
#   'kennedy'],
#  ['speaker',
#   'florida',
#   'house',
#   'consistently',
#   'offered',
#   'leaner',
#   'budgets',
#   'governor',
#   'offered'],
#  ['halfway', 'goal', 'creating', 'jobs'],
#  ['supreme', 'court', 'social', 'security', 'guaranteed'],
#  ['saysmichael',
#   'bennet',
#   'close',
#   'guantanamo',
#   'bay',
#   'prisonand',
#   'bring',
#   'terrorists',
#   'colorado'],
#  ['oregonians',
#   'amazing',
#   'no-cost',
#   'fight',
#   'abortion',
#   'political',
#   'donations'],
#  ['president', 'bring', 'syrian', 'iraqi', 'refugees', 'country'],
#  ['vast',
#   'majority',
#   'arriving',
#   'immigrants',
#   'government',
#   'source',
#   'prosperity',
#   'support'],
#  ['newt', 'gingrichs', 'immigration', 'plan', 'offers', 'doorway', 'amnesty'],
#  ['caprio', 'career', 'politician', 'private', 'sector'],
#  ['rhode',
#   'island',
#   'percent',
#   'workers',
#   'temporary',
#   'disability',
#   'insurance',
#   'program',
#   'jersey',
#   'rate',
#   'percent'],
#  ['spending',
#   'social',
#   'security',
#   'federal',
#   'health',
#   'care',
#   'debt',
#   'exceed',
#   'tax',
#   'revenue'],
#  ['president', 'obama', 'money', 'wall', 'street', 'campaign'],
#  ['donald', 'trump', 'nuclear', 'proliferation'],
#  ['hillary', 'clinton', 'lobbyists'],
#  ['barack', 'obama', 'business'],
#  ['arizona', 'immigration', 'law', 'expressly', 'bans', 'racial', 'profiling'],
#  ['rick',
#   'perry',
#   'begging',
#   'federal',
#   'government',
#   'send',
#   'coast',
#   'guard',
#   'patrol',
#   'lakes',
#   'mexico',
#   'border'],
#  ['veterans', 'died', 'waiting', 'care'],
#  ['spending', 'percent', 'economy', 'government'],
#  ['rob', 'cornilles', 'supports', 'privatizing', 'medicare'],
#  ['dan', 'branch', 'expand', 'third-trimester', 'abortions', 'texas'],
#  ['democrats',
#   'steady',
#   'progress',
#   'creating',
#   'jobs',
#   'improving',
#   'schools'],
#  ['michigan',
#   'massachusetts',
#   'raised',
#   'bottle',
#   'deposit',
#   'afford',
#   'program',
#   'redemptions',
#   'profit'],
#  ['admit', 'revenue', 'education'],
#  ['fought', 'developers', 'draining', 'everglades'],
#  ['ron',
#   'johnson',
#   'calls',
#   'social',
#   'security',
#   'ponzi',
#   'scheme',
#   'privatize',
#   'program'],
#  ['cities',
#   'type',
#   'policies',
#   'passed',
#   'referring',
#   'north',
#   'carolinas',
#   'house'],
#  ['climate', 'change', 'growth', 'terrorism'],
#  ['jobs', 'includes', 'president', 'obamas', 'tax', 'soup', 'kitchens'],
#  ['obama',
#   'administration',
#   'spent',
#   'taxpayer',
#   'dollars',
#   'electric',
#   'cars',
#   'finland',
#   'windmills',
#   'china'],
#  ['sarah',
#   'mayor',
#   'wasilla',
#   'highly',
#   'respected',
#   'city',
#   'librarian',
#   'librarian',
#   'refused',
#   'removing',
#   'library',
#   'books',
#   'sarah',
#   'removed'],
#  ['milwaukee',
#   'approves',
#   'reducing',
#   'maximum',
#   'forfeiture',
#   'marijuana',
#   'possession',
#   'city',
#   'bicycle',
#   'violations',
#   'forfeiture'],
#  ['illegal', 'immigrants'],
#  ['rick', 'perry', 'wrote', 'letter', 'supporting', 'hillarycare'],
#  ['patent',
#   'trademark',
#   'office',
#   'received',
#   'complaints',
#   'washington',
#   'redskins'],
#  ['presidents',
#   'health',
#   'care',
#   'proposals',
#   'americans',
#   'premiums',
#   'increased',
#   'decreased',
#   'hundreds',
#   'millions',
#   'people',
#   'lose',
#   'current',
#   'insurance',
#   'coverage'],
#  ['mexican', 'immigrants', 'law-abiding', 'citizens', 'statistic'],
#  ['chris', 'christie', 'vetoed', 'jobs', 'package', 'bills'],
#  ['american', 'jobs', 'solar', 'industry', 'coal', 'mining'],
#  ['illinois',
#   'gubernatorial',
#   'candidate',
#   'bradys',
#   'priority',
#   'winning',
#   'primary',
#   'sponsor',
#   'mass-euthanize',
#   'sheltered',
#   'dogs',
#   'cats',
#   'gas',
#   'chambers'],
#  ['barack', 'obama', 'economy', 'worsened', 'president', 'united'],
#  ['romney', 'failed', 'action', 'sanctuary', 'cities', 'massachusetts'],
#  ['jersey',
#   'jobs',
#   'pre-recession',
#   'peak',
#   'chris',
#   'christie',
#   'jersey',
#   'trailed',
#   'rest',
#   'america',
#   'unemployment',
#   'consecutive',
#   'months'],
#  ['thomas', 'eric', 'duncan', 'united', 'elevated', 'temperature'],
#  ['afghanistan', 'foreign', 'land', 'conducting', 'war', 'nations', 'history'],
#  ['gas', 'prices', 'obama', 'office'],
#  ['webster',
#   'sponsored',
#   'create',
#   'form',
#   'marriage',
#   'trap',
#   'women',
#   'abusive',
#   'relationships'],
#  ['judges', 'benefits', 'cost'],
#  ['lot', 'casinos', 'country', 'bankrupt'],
#  ['businesses', 'create', 'percent', 'jobs', 'america'],
#  ['seniors',
#   'coverage',
#   'medicare',
#   'advantage',
#   'share',
#   'health',
#   'care',
#   'reform'],
#  ['school', 'kids', 'arrested', 'florida', 'florida', 'nations', 'leader'],
#  ['texas', 'country', 'economy', 'rank'],
#  ['oil', 'rigs', 'operation', 'united', 'rest', 'combined'],
#  ['payday', 'lenders', 'profit', 'poor', 'charging', 'percent'],
#  ['social',
#   'security',
#   'trust',
#   'fund',
#   'sound',
#   'function',
#   'time',
#   'pay',
#   'percent',
#   'benefits',
#   'people',
#   'earned'],
#  ['commitment',
#   'voters',
#   'incumbent',
#   'ohio',
#   'break',
#   'pledge',
#   'vote',
#   'ted',
#   'stricklands',
#   'income',
#   'tax',
#   'hike',
#   'defeated',
#   'soundly',
#   'tuesday'],
#  ['obama',
#   'administration',
#   'shut',
#   'amber',
#   'alert',
#   'program',
#   'government',
#   'shutdown'],
#  ['republicans', 'percent', 'muslim', 'vote'],
#  ['americas',
#   'prison',
#   'population',
#   'exploding',
#   'america',
#   'percentage',
#   'people',
#   'bars',
#   'nation'],
#  ['hearing',
#   'rep',
#   'gabrielle',
#   'giffords',
#   'suggested',
#   'gen',
#   'david',
#   'petraeus',
#   'army',
#   'emphasis',
#   'environmentally',
#   'damaging',
#   'methods',
#   'stabbing',
#   'clubbing',
#   'enemy',
#   'forces',
#   'minimize',
#   'carbon',
#   'output'],
#  ['single',
#   'republican',
#   'senators',
#   'blocked',
#   'raise',
#   'minimum',
#   'wage',
#   'receive',
#   'cost-of',
#   'living',
#   'adjustment',
#   'january'],
#  ['texas', 'male', 'babies', 'vote', 'day', 'jose'],
#  ['marco',
#   'rubio',
#   'voted',
#   'authorizing',
#   'president',
#   'obama',
#   'strike',
#   'syria',
#   'assad',
#   'chemical',
#   'weapons',
#   'people'],
#  ['cash', 'clunkers', 'program', 'local', 'junkyard', 'tow', 'house'],
#  ['republican', 'guts', 'recognize', 'climate', 'change', 'real'],
#  ['people', 'hours', 'wages', 'income', 'percent'],
#  ['david', 'dewhurst', 'record', 'promoting', 'income', 'tax'],
#  ['pleasant',
#   'beach',
#   'beaches',
#   'privately',
#   'owned',
#   'operated',
#   'businesses',
#   'jenkinsons'],
#  ['percent', 'americans', 'changed', 'mind', 'war', 'afghanistan', 'conclude'],
#  ['people', 'killed', 'mexico', 'border'],
#  ['ohio',
#   'lowest',
#   'unemployment',
#   'rates',
#   'nation',
#   'leading',
#   'pack',
#   'terms',
#   'job',
#   'creation'],
#  ['obama',
#   'health',
#   'reform',
#   'law',
#   'denies',
#   'millions',
#   'access',
#   'affordable',
#   'insurance'],
#  ['hb', 'moved', 'needle', 'iota', 'north', 'carolinas', 'economy'],
#  ['close',
#   'federal',
#   'prison',
#   'population',
#   'consists',
#   'illegal',
#   'immigrants'],
#  ['rick', 'scott', 'called', 'education', 'core', 'function'],
#  ['family', 'council', 'government', 'agencies', 'terrorist'],
#  ['rep',
#   'jim',
#   'weidner',
#   'proposed',
#   'health',
#   'care',
#   'oregons',
#   'children'],
#  ['election',
#   'tom',
#   'kean',
#   'largest',
#   'winning',
#   'margin',
#   'gubernatorial',
#   'candidate',
#   'jersey',
#   'history'],
#  ['obamacare', 'biggest', 'tax', 'increase', 'american', 'history'],
#  ['barack', 'obama', 'ready', 'commander', 'chief'],
#  ['median',
#   'male',
#   'worker',
#   'country',
#   'raise',
#   'inflation',
#   'adjusted',
#   'basically'],
#  ['milwaukee', 'mayor', 'tom', 'barrett', 'held', 'property', 'taxes'],
#  ['house',
#   'representatives',
#   'raised',
#   'campaign',
#   'funds',
#   'election',
#   'contributions'],
#  ['gridlock',
#   'washington',
#   'percent',
#   'bills',
#   'passed',
#   'assembly',
#   'bipartisan',
#   'support'],
#  ['josh',
#   'mandel',
#   'lying',
#   'record',
#   'rating',
#   'ohios',
#   'investment',
#   'fund',
#   'improved'],
#  ['rick', 'scott', 'family', 'leased', 'land', 'drilling', 'hide'],
#  ['money', 'lease', 'ohio', 'turnpike'],
#  ['decade',
#   'america',
#   'budget',
#   'surplus',
#   'time',
#   'office',
#   'one-year',
#   'deficit',
#   'projected',
#   'deficits',
#   'decade'],
#  ['president', 'nominations', 'confirmed', 'defeated'],
#  ['taxpayers',
#   'forced',
#   'fund',
#   'feisal',
#   'abdul',
#   'raufs',
#   'trip',
#   'middle',
#   'east'],
#  ['milwaukee',
#   'county',
#   'taxpayers',
#   'paid',
#   'settle',
#   'lawsuit',
#   'decision',
#   'sheriff',
#   'david',
#   'clarke',
#   'jr',
#   'untrained',
#   'corrections',
#   'officers',
#   'deputies',
#   'patrol',
#   'lakefront'],
#  ['justice',
#   'department',
#   'policies',
#   'fbi',
#   'director',
#   'james',
#   'comey',
#   'discussing',
#   'details',
#   'federal',
#   'investigation',
#   'close',
#   'election'],
#  ['democratic',
#   'presidents',
#   'considerably',
#   'effective',
#   'creating',
#   'private-sector',
#   'jobs'],
#  ['joe',
#   'biden',
#   'voted',
#   'gulf',
#   'war',
#   'opposed',
#   'surge',
#   'partition',
#   'iraq'],
#  ['rush',
#   'limbaugh',
#   'country',
#   'fail',
#   'president',
#   'barack',
#   'obama',
#   'succeed'],
#  ['percent',
#   'american',
#   'people',
#   'percent',
#   'income',
#   'america',
#   'george',
#   'bush',
#   'president'],
#  ['military', 'recruiting', 'harvard', 'single', 'day', 'time', 'kagan'],
#  ['rick', 'perrys', 'plan', 'texas', 'cut', 'funding', 'public', 'schools'],
#  ['david',
#   'perdue',
#   'abolish',
#   'department',
#   'education',
#   'cost',
#   'georgia',
#   'schools',
#   'eliminate',
#   'millions',
#   'student',
#   'loans'],
#  ['paul', 'ryan', 'budget', 'proposal', 'privatize', 'medicare'],
#  ['school',
#   'students',
#   'arrested',
#   'campus',
#   'graduate',
#   'times',
#   'graduate',
#   'appeared',
#   'court'],
#  ['united', 'imprisons', 'nation'],
#  ['marco', 'rubio', 'border'],
#  ['federal',
#   'spending',
#   'education',
#   'grown',
#   'percent',
#   'scores',
#   'remain',
#   'flat'],
#  ['cuts', 'medicare', 'affect', 'people', 'paid', 'paid'],
#  ['david',
#   'alameel',
#   'thousands',
#   'dollars',
#   'support',
#   'republican',
#   'party',
#   'candidates',
#   'including',
#   'john',
#   'cornyn',
#   'greg',
#   'abbott'],
#  ['american', 'healthcare', 'burns', 'percent', 'national', 'gdp', 'close'],
#  ['providences', 'port', 'miles', 'closer', 'europe', 'eastern', 'port'],
#  ['photo', 'purchase', 'sudafed', 'texas'],
#  ['percent', 'housing', 'portlands', 'pearl', 'district', 'affordable'],
#  ['allowing',
#   'payroll',
#   'tax',
#   'holiday',
#   'expire',
#   'costing',
#   'estimated',
#   'jobs'],
#  ['hillary',
#   'clinton',
#   'supported',
#   'nafta',
#   'permanent',
#   'china',
#   'trade',
#   'pennsylvania',
#   'lost',
#   'thousands',
#   'jobs'],
#  ['numerous',
#   'studies',
#   'so-called',
#   'right-to',
#   'laws',
#   'generate',
#   'jobs',
#   'economic',
#   'growth'],
#  ["obama's",
#   'budget',
#   'plan',
#   'national',
#   'debt',
#   'percent',
#   'gross',
#   'national',
#   'product',
#   'historically',
#   'percent'],
#  ['hillary',
#   'clinton',
#   'veterans',
#   'affairs',
#   'scandal',
#   'over-exaggerated',
#   'satisfied'],
#  ['driven', 'health', 'care', 'costs', 'lowest'],
#  ['president',
#   'barack',
#   "obama's",
#   'initial',
#   'response',
#   'heard',
#   'christmas',
#   'underwear',
#   'bomber',
#   'isolated',
#   'extremist'],
#  ['sen',
#   'sherrod',
#   'brown',
#   'admitted',
#   'stimulus',
#   'law',
#   'failed',
#   'attacking',
#   'republicans',
#   'americans',
#   'taxes',
#   'claims',
#   'stimulus',
#   'taxes'],
#  ['lot', 'people', 'rich', 'pay', 'tax', 'rate', 'percent'],
#  ['charleston',
#   'shootershould',
#   'gun',
#   'universal',
#   'background',
#   'check',
#   'fast'],
#  ['sixty-five', 'percent', 'iraqi', 'people', 'shoot', 'american', 'soldier'],
#  ['judges',
#   'thrown',
#   'legal',
#   'challenges',
#   'health',
#   'care',
#   'law',
#   'rejected',
#   'notion',
#   'health',
#   'care',
#   'law',
#   'unconstitutional'],
#  ['chris',
#   'christies',
#   'proposal',
#   'reduce',
#   'income',
#   'taxes',
#   'tax',
#   'cut',
#   'rich',
#   'governor'],
#  ['warren', 'buffett', 'support'],
#  ['george',
#   'lemieux',
#   'republicans',
#   'voted',
#   'president',
#   'barack',
#   'obamas',
#   'jobs'],
#  ['precinct',
#   'allen',
#   'west-patrick',
#   'murphy',
#   'recount',
#   'registered',
#   'voters',
#   'guatemalan',
#   'community',
#   'tally',
#   'voted'],
#  ['people', 'unemployment', 'office', 'unemployment'],
#  ['person',
#   'kathleen',
#   'sebelius',
#   'determine',
#   'year-old',
#   'lung',
#   'patient',
#   'sarah',
#   'murnaghan',
#   'live',
#   'die'],
#  ['ron',
#   'klein',
#   'repeatedly',
#   'voted',
#   'favor',
#   'amnesty',
#   'illegal',
#   'immigrants'],
#  ['local',
#   'law',
#   'enforcement',
#   'access',
#   'obamacare',
#   'data',
#   'hubs',
#   'treasure',
#   'trove',
#   'personal',
#   'info'],
#  ['tenure', 'mayor', 'houstons', 'crime', 'rates', 'drop', 'lowest', 'levels'],
#  ['barack',
#   'obamas',
#   'columbia',
#   'university',
#   'foreign',
#   'student',
#   'barry',
#   'soetoro'],
#  ['john',
#   'mccain',
#   'richest',
#   'people',
#   'senate',
#   'filled',
#   'millionaires',
#   'solution',
#   'housing',
#   'crisis',
#   'people',
#   'job',
#   'skip',
#   'vacations'],
#  ['terry', 'mcauliffe', 'raise', 'taxes', 'pay', 'infinite', 'promises'],
#  ['hypocrisy',
#   'clinton',
#   'foundation',
#   'male',
#   'staff',
#   'average',
#   'female',
#   'staff'],
#  ['federal', 'violence', 'women', 'domestic', 'violence', 'fallen', 'percent'],
#  ['federal',
#   'law',
#   'enforcement',
#   'officers',
#   'cut',
#   'questioning',
#   'christmas',
#   'day',
#   'underwear',
#   'bomber',
#   'miranda',
#   'warning',
#   'minutes',
#   'questioning'],
#  ['legalizing', 'illegal', 'immigrants'],
#  ['pregnancies', 'unintended'],
#  ['borrowing',
#   'saudi',
#   'money',
#   'saudi',
#   'oil',
#   'result',
#   'dependency',
#   'debt'],
#  ['homes', 'sale', 'oswego', 'lake'],
#  ['president',
#   'president',
#   'lost',
#   'jobs',
#   'private',
#   'sector',
#   'complaining',
#   'public',
#   'sector',
#   'gained',
#   'public',
#   'sector',
#   'jobs'],
#  ['percent', 'pay', 'entire', 'revenue', 'country'],
#  ['difference',
#   'previous',
#   'headed',
#   'brought',
#   'total',
#   'saved',
#   'property',
#   'tax',
#   'money'],
#  ['chris', 'christie', 'increased', 'taxes'],
#  ['united', 'growers', 'dairies', 'bring', 'workforce', 'legally'],
#  ['education', 'funding'],
#  ['college', 'tuition', 'nationwide', 'times', 'rate', 'inflation'],
#  ['sen', 'rob', 'portman', 'irresponsible', 'cut', 'medicare'],
#  ['dekalb', 'school', 'construction', 'projects', 'budget'],
#  ['palin',
#   'supported',
#   'right-wing',
#   'extremist',
#   'pat',
#   'buchanan',
#   'president'],
#  ['sen',
#   'sherrod',
#   'brown',
#   'voted',
#   'block',
#   'american',
#   'energy',
#   'production',
#   'increase',
#   'energy',
#   'taxes'],
#  ['jeanne',
#   'shaheen',
#   'voted',
#   'measure',
#   'amounted',
#   'national',
#   'energy',
#   'tax'],
#  ['washington',
#   'strictest',
#   'gun',
#   'laws',
#   'country',
#   'passed',
#   'violence',
#   'skyrocketed'],
#  ['presidents',
#   'barack',
#   'obama',
#   'republicans',
#   'democrats',
#   'expand',
#   'health',
#   'care',
#   'americans'],
#  ['fighting',
#   'toughen',
#   'penalties',
#   'workplace',
#   'gender',
#   'discrimination',
#   'sen',
#   'glenn',
#   'grothman',
#   'women',
#   'belonged',
#   'workplace',
#   'belonged',
#   'cooking',
#   'cleaning',
#   'babies'],
#  ['revenue',
#   'raised',
#   'buffett',
#   'rule',
#   'infrastructure',
#   'create',
#   'infrastructure',
#   'jobs'],
#  ['proper', 'collective', 'noun', 'baboons', 'congress'],
#  ['repeatedly',
#   'predatory',
#   'loans',
#   'mortgage',
#   'target',
#   'african-american',
#   'latino',
#   'communities'],
#  ['starting',
#   'december',
#   'jobs',
#   'created',
#   'texas',
#   'period',
#   'rest',
#   'country',
#   'lost',
#   'jobs'],
#  ['health',
#   'reform',
#   'legislation',
#   'washington',
#   'passed',
#   'difficult',
#   'hire',
#   'increased',
#   'costs',
#   'employers'],
#  ['cbo', 'congressional', 'budget', 'office', 'obamacare', 'kill', 'jobs'],
#  ['thompson', 'voted', 'caps', 'damages', 'legal', 'fairer'],
#  ['texas', 'fiscal', 'money', 'reserve', 'combined'],
#  ['strategic', 'petroleum', 'reserve'],
#  ['immigrants', 'fertile'],
#  ['proposed', 'education', 'cut', "teacher's", 'pay'],
#  ['uninsured', 'people', 'massachusetts', 'mandates', 'passed'],
#  ['firearms',
#   'homicides',
#   'percent',
#   'texas',
#   'passed',
#   'concealed-gun',
#   'permit',
#   'law'],
#  ['percent',
#   'women',
#   'seeking',
#   'abortion',
#   'decide',
#   'abortion',
#   'ultrasound'],
#  ['spend', 'defense', 'gdp', 'time', 'pearl', 'harbor'],
#  ['rid', 'income', 'tax', 'revenue'],
#  ['scott',
#   'walker',
#   'ban',
#   'common',
#   'forms',
#   'birth',
#   'control',
#   'including',
#   'pill'],
#  ['jason',
#   'kander',
#   'supports',
#   'obamas',
#   'plan',
#   'bring',
#   'remaining',
#   'suspected',
#   'terrorists',
#   'soil'],
#  ['shelby', 'county', 'donated', 'schools', 'city', 'memphis'],
#  ['intelligence',
#   'officials',
#   'toldevery',
#   'congress',
#   'including',
#   'president',
#   'attacked',
#   'threat',
#   'emanating',
#   'syria',
#   'iraq'],
#  ['suburbs',
#   'inundated',
#   'residents',
#   'atlanta',
#   'housing',
#   'projects',
#   'absolutely'],
#  ['july',
#   'mitt',
#   'romney',
#   'helped',
#   'locate',
#   'missing',
#   'teenage',
#   'daughter',
#   'partner',
#   'bain',
#   'capital'],
#  ['blames',
#   'mike',
#   'mcintyre',
#   'nancy',
#   'pelosi',
#   'straight',
#   'cost-of',
#   'living',
#   'increases',
#   'social',
#   'security',
#   'beneficiaries'],
#  ['government', 'bank', 'account', 'health', 'care', 'transfers', 'knowing'],
#  ['mechanisms', 'shut', 'internet', 'privately'],
#  ['american',
#   'people',
#   'support',
#   'defunding',
#   'obamacare',
#   'oppose',
#   'shutting',
#   'government'],
#  ['report',
#   'gop',
#   'insisting',
#   'social',
#   'security',
#   'fiscalcliff',
#   'false',
#   'btw',
#   'supported',
#   'barackobama'],
#  ['played',
#   'clips',
#   'president',
#   'obama',
#   'bring',
#   'knife',
#   'fight',
#   'bring',
#   'gun'],
#  ['people', 'rhode', 'island', 'same-sex', 'marriage'],
#  ['rep',
#   'paul',
#   'ryans',
#   'medicare',
#   'plan',
#   'lines',
#   'pockets',
#   'private',
#   'insurance',
#   'companies',
#   'increases',
#   'costs',
#   'seniors',
#   'reduce',
#   'deficit'],
#  ['congress', 'connie', 'mack', 'iv', 'missed', 'votes'],
#  ['kids', 'drop', 'school', 'college', 'start', 'career'],
#  ['gen', 'eisenhower', 'saluted', 'military', 'personnel', 'president'],
#  ['wisconsins',
#   'governor',
#   'cuts',
#   'perquisites',
#   'plans',
#   'leave',
#   'workers',
#   'private',
#   'sector',
#   'counterparts'],
#  ['airplane', 'people', 'list', 'gun'],
#  ['percent', 'republicans', 'support', 'affordable', 'care'],
#  ['spent', 'afterschool', 'programs', 'save', 'crime', 'costs'],
#  ['federal', 'government', 'cash', 'flow', 'pay', 'bills', 'default'],
#  ['alex',
#   'sink',
#   'failed',
#   'florida',
#   'homeowners',
#   'predatory',
#   'lending',
#   'practices'],
#  ['percent',
#   'mid-size',
#   'banks',
#   'loan',
#   'money',
#   'businesses',
#   'wiped',
#   'dodd-frank',
#   'passed'],
#  ['check', 'library', 'book', 'photo'],
#  ['starbucks', 'christmas', 'brand', 'cups'],
#  ['atmospheric',
#   'conditions',
#   'push',
#   'footballs',
#   'pressure',
#   'one-and',
#   'a-half',
#   'pounds',
#   'square',
#   'inch'],
#  ['hillary',
#   'clinton',
#   'supports',
#   'unlimited',
#   'abortion',
#   'demand',
#   'moment',
#   'birth',
#   'including',
#   'partial-birth',
#   'abortion',
#   'taxpayer',
#   'funding'],
#  ['legislation',
#   'cleared',
#   'georgia',
#   'house',
#   'children',
#   'legal',
#   'refugees',
#   'scholarships',
#   'attend',
#   'private',
#   'schools'],
#  ['losing',
#   'jobs',
#   'months',
#   'bush',
#   'administration',
#   'adding',
#   'private',
#   'sector',
#   'jobs',
#   'months'],
#  ['star', 'ohio', 'fund', 'received', 'credit', 'rating', 'funds', 'receive'],
#  ['taxpayers',
#   'hook',
#   'proposed',
#   'atlanta',
#   'falcons',
#   'stadium',
#   'funds',
#   'repaid',
#   'money',
#   'outsiders'],
#  ['months', 'businesses', 'created', 'jobs', 'created', 'jobs'],
#  ['leaving', 'missouri', 'lone', 'star'],
#  ['college', 'loan', 'loan', 'united', 'refinance', 'rates'],
#  ['house',
#   'representatives',
#   'passed',
#   'resolution',
#   'disapproval',
#   'condemn',
#   "member's",
#   'behavior'],
#  ['competitors', 'immigration'],
#  ['international',
#   'reports',
#   'united',
#   'industrialized',
#   'nations',
#   'academic',
#   'achievement'],
#  ['people',
#   'country',
#   'full-time',
#   'job',
#   'doctor',
#   'sick',
#   'people',
#   'government',
#   'feed',
#   'families',
#   'owe'],
#  ['policy',
#   'mistakes',
#   'clintons',
#   'degree',
#   'situation',
#   'mass',
#   'incarceration'],
#  ['raised',
#   'average',
#   'family',
#   'income',
#   'percent',
#   'tenure',
#   'arkansas',
#   'governor'],
#  ['build', 'high-speed', 'train', 'miles', 'hour'],
#  ['cbo',
#   'estimates',
#   'extending',
#   'bush',
#   'tax',
#   'cuts',
#   'add',
#   'jobs',
#   'jobs'],
#  ['president',
#   'reagan',
#   'raised',
#   'debt',
#   'ceiling',
#   'times',
#   'george',
#   'bush',
#   'times'],
#  ['david',
#   'cay',
#   'johnston',
#   'average',
#   'american',
#   'pays',
#   'percent',
#   'income',
#   'federal',
#   'taxes',
#   'richest',
#   'americans',
#   'pay',
#   'percent',
#   'income',
#   'federal',
#   'taxes'],
#  ['americans', 'covered', 'health', 'insurance'],
#  ['corporate',
#   'income',
#   'tax',
#   'accounted',
#   'percent',
#   'federal',
#   'tax',
#   'revenue',
#   'record-breaking',
#   'profits',
#   'corporate',
#   'taxes',
#   'bring',
#   'percent'],
#  ['texas', 'created', 'percent', 'jobs', 'nationwide'],
#  ['two-thirds', 'targeted', 'irs', 'scrutiny', 'conservative'],
#  ['class',
#   'patrice',
#   'lumumba',
#   'university',
#   'moscow',
#   'mahmoud',
#   'abbas',
#   'class',
#   'ali',
#   'khamenei',
#   'established',
#   'relationships',
#   'vladimir',
#   'putin'],
#  ['week',
#   'texas',
#   'board',
#   'education',
#   'sboe',
#   'led',
#   'rick',
#   'perrys',
#   'appointee',
#   'voted',
#   'remove',
#   'thomas',
#   'jefferson',
#   'social',
#   'studies',
#   'textbook',
#   'standards',
#   'thomas',
#   'jefferson',
#   'deleted',
#   'list',
#   'historical',
#   'figures',
#   'inspired',
#   'political',
#   'change'],
#  ['senator',
#   'salary',
#   'perks',
#   'bernie',
#   'percent',
#   'paid',
#   'percent',
#   'taxes'],
#  ['pull',
#   'truth',
#   'matter',
#   'started',
#   'troops',
#   'physically',
#   'iraq',
#   'logistically'],
#  ['richest',
#   'americans',
#   'increased',
#   'wealth',
#   'republican',
#   'budget',
#   'require',
#   'americans',
#   'contribute',
#   'penny',
#   'deficit',
#   'reduction'],
#  ['foster',
#   'mayor',
#   'rick',
#   'kriseman',
#   'ineffective',
#   'florida',
#   'house',
#   'representatives',
#   'legislation',
#   'passed',
#   'house',
#   'krisemans'],
#  ['texas', 'routinely', 'lot', 'federal', 'spending', 'pays', 'taxes'],
#  ['cell', 'phone', 'public', 'month'],
#  ['offered',
#   'savings',
#   'savings',
#   'contract',
#   'negotiations',
#   'city',
#   'milwaukee'],
#  ['clackamas',
#   'county',
#   'commissioners',
#   'approved',
#   're-negotiated',
#   'agreement',
#   'countys',
#   'contribution',
#   'trimets',
#   'portland-milwaukie',
#   'light',
#   'rail',
#   'project'],
#  ['texas', 'felonies', 'commit', 'oyster'],
#  ['obama',
#   'administration',
#   'unwinding',
#   'nations',
#   'welfare-to',
#   'requirements'],
#  ['electric',
#   'car',
#   'sales',
#   'georgia',
#   'dropped',
#   'dramatically',
#   'tax',
#   'credit',
#   'eliminated',
#   'annual',
#   'registration',
#   'fee',
#   'imposed',
#   'july'],
#  ['redskins',
#   'training',
#   'camp',
#   'deal',
#   'generated',
#   'private',
#   'investment',
#   'city'],
#  ['gop', 'budget', 'plan', 'cut', 'jobs'],
#  ['people', 'living', 'country', 'born', 'anytime', 'history', 'country'],
#  ['hillary',
#   'clinton',
#   'defended',
#   'syrias',
#   'president',
#   'assad',
#   'reformer',
#   'start',
#   'countrys',
#   'civil',
#   'war'],
#  ['postal',
#   'services',
#   'financial',
#   'losses',
#   'result',
#   'law',
#   'drains',
#   'post',
#   'office',
#   'revenue',
#   'postal',
#   'service',
#   'forced',
#   'overpay',
#   'billions',
#   'federal',
#   'accounts'],
#  ['federal',
#   'department',
#   'budget',
#   'bills',
#   'delayed',
#   'opposition',
#   'amendments',
#   'ban',
#   'confederate',
#   'battle',
#   'flag',
#   'sales',
#   'federal',
#   'building',
#   'gift',
#   'shops'],
#  ['voted', 'tax', 'increases', 'hurting', 'middle', 'class', 'businesses'],
#  ['house', 'representatives', 'jobs', 'bills', 'passed', 'bipartisan'],
#  ['sheila',
#   'jackson',
#   'lee',
#   'texas',
#   'hey',
#   'wrinkly',
#   'white-aged',
#   'has-beens',
#   'time',
#   'die',
#   'generation',
#   'spot',
#   'planet'],
#  ['republican',
#   'business',
#   'tax',
#   'cut',
#   'spends',
#   'google',
#   'searches',
#   'job',
#   'creation'],
#  ['law',
#   'operator',
#   'iron',
#   'ore',
#   'northern',
#   'wisconsin',
#   'pristine',
#   'streams',
#   'ponds',
#   'waste'],
#  ['america', 'highest-taxed', 'nations'],
#  ['black', 'america', 'country', 'wealthiest', 'nation'],
#  ['republicans',
#   'election',
#   'graduation',
#   'rate',
#   'wisconsin',
#   'percent',
#   'percent',
#   'black',
#   'graduation',
#   'rate',
#   'percent',
#   'percent',
#   'latino',
#   'graduation',
#   'rate',
#   'percent',
#   'percent'],
#  ['estimated',
#   'percent',
#   'guns',
#   'sold',
#   'america',
#   'sold',
#   'private',
#   'unlicensed',
#   'sellers',
#   'online',
#   'gun'],
#  ['deadliest', 'war', 'afghanistan', 'american', 'forces'],
#  ['florida', 'teachers', 'paid', 'national', 'average'],
#  ['rick',
#   'perry',
#   'governor',
#   'texas',
#   'country',
#   'population',
#   'graduates',
#   'school'],
#  ['amanda', 'fritz', 'manages', 'percent', 'city', 'operations'],
#  ['streetcar',
#   'project',
#   'planned',
#   'mayor',
#   'tom',
#   'barrett',
#   'style',
#   'trolley'],
#  ['americans', 'doubled', 'money', 'spending', 'child', 'education', 'worse'],
#  ['polls', 'floridians', 'repeal', 'affordable', 'care'],
#  ['congressman',
#   'pascrell',
#   'voted',
#   'remove',
#   'public',
#   'option',
#   'affordable',
#   'health',
#   'care'],
#  ['lawmakers',
#   'paid',
#   'off-season',
#   'efforts',
#   'time',
#   'lead',
#   'drawing',
#   'borders',
#   'would-be',
#   'cities'],
#  ['greg',
#   'abbott',
#   'surrogates',
#   'referred',
#   'women',
#   'victims',
#   'rape',
#   'incest',
#   'confronting',
#   'minor',
#   'issue'],
#  ['offshore', 'drilling', 'energy'],
#  ['proposed', 'medical', 'marijuana', 'amendment', 'florida', 'refills'],
#  ['data-storing',
#   'microchip',
#   'implanted',
#   'majority',
#   'people',
#   'opt',
#   'covered',
#   'public',
#   'health',
#   'care',
#   'option'],
#  ['enacting',
#   'right-to',
#   'carry',
#   'expanding',
#   'rights',
#   'sex',
#   'offenders',
#   'terrorists',
#   'child',
#   'predators',
#   'abusers',
#   'carry',
#   'concealed',
#   'weapons',
#   'lines'],
#  ['missed', 'vote'],
#  ['treasurers',
#   'office',
#   'saved',
#   'management',
#   'costs',
#   'oversight',
#   'public',
#   'investments'],
#  ['georgia',
#   'send',
#   'money',
#   'child',
#   'charter',
#   'schools',
#   'budget',
#   'cuts',
#   'applied',
#   'charter',
#   'schools'],
#  ['jorge', 'elorza', 'impose', 'municipal', 'income', 'tax'],
#  ['supreme', 'court', 'overrule', 'branchesof', 'government'],
#  ['roughly', 'ri', 'criminal', 'record'],
#  ['nathan',
#   'deal',
#   'cut',
#   'hope',
#   'scholarship',
#   'program',
#   'literally',
#   'georgians',
#   'college',
#   'technical',
#   'training',
#   'badly',
#   'raise',
#   'chance',
#   'job'],
#  ['governor',
#   'arkansas',
#   'cut',
#   'taxes',
#   'fees',
#   'times',
#   'saving',
#   'taxpayers',
#   'left',
#   'surplus'],
#  ['raised', 'taxes', 'time', 'governor', 'jersey'],
#  ['massachusetts',
#   'public',
#   'schools',
#   'teach',
#   'kids',
#   'kindergartners',
#   'gay',
#   'marriage'],
#  ['best-known', 'americans'],
#  ['accepting', 'legal', 'immigrants', 'history', 'united'],
#  ['congress',
#   'bewildered',
#   'scope',
#   'reach',
#   'spying',
#   'apparatus',
#   'explicitly',
#   'rejected',
#   'amendment',
#   'calling',
#   'disclosure'],
#  ['people', 'florida', 'die', 'result', 'expanding', 'medicaid', 'day'],
#  ['maggie',
#   'hassans',
#   'budget',
#   'proposal',
#   'raises',
#   'taxes',
#   'businesses',
#   'increases',
#   'taxes',
#   'fees'],
#  ['washington', 'politicians', 'spend', 'teach', 'moroccans', 'pottery'],
#  ['hillary', 'clinton', 'starts', 'percent', 'country'],
#  ['saysrand', 'paulhas', 'budgets', 'cut', 'military'],
#  ['receive',
#   'foreign',
#   'money',
#   'spending',
#   'huge',
#   'sums',
#   'influence',
#   'american',
#   'elections'],
#  ['legislative', 'cuts', 'texas', 'spending', 'average', 'student'],
#  ['current',
#   'rate',
#   'president',
#   'obama',
#   'debt',
#   'united',
#   'america',
#   'term',
#   'previous',
#   'presidents',
#   'combined'],
#  ['saudi', 'arabia', 'started', 'al-qaida'],
#  ['williamson',
#   'county',
#   'attorney',
#   'jana',
#   'duty',
#   'prosecuted',
#   'single',
#   'adult',
#   'felony'],
#  ['fundraising', 'grassroots', 'support', 'unmatched'],
#  ['issue', 'illegal', 'negotiate', 'firefighters', 'job'],
#  ['unemployment',
#   'rate',
#   'improving',
#   'reflect',
#   'real',
#   'job',
#   'creation',
#   'caused',
#   'shrinking',
#   'actual',
#   'labor',
#   'force'],
#  ['scott',
#   'walker',
#   'hired',
#   'convicted',
#   'assembly',
#   'speaker',
#   'scott',
#   'jensen',
#   'oversee',
#   'raid',
#   'employee',
#   'retirement',
#   'balance',
#   'budget'],
#  ['obama', 'voted', 'cut', 'funding', 'american', 'troops', 'battlefield'],
#  ['appears',
#   'wisconsins',
#   'apply',
#   'green',
#   'bay',
#   'packers',
#   'players',
#   'union'],
#  ['so-called',
#   'defense',
#   'minister',
#   'peoples',
#   'republic',
#   'donetsk',
#   'posted',
#   'bragging',
#   'social',
#   'media',
#   'posting',
#   'shot',
#   'military',
#   'transport',
#   'apparent',
#   'civilian',
#   'pulled',
#   'social',
#   'media'],
#  ['democrats',
#   'falling',
#   'raise',
#   'taxes',
#   'faster',
#   'raise',
#   'taxes',
#   'percent'],
#  ['job',
#   'growth',
#   'sectors',
#   'leisure',
#   'hospitality',
#   'jobs',
#   'fall',
#   'restaurant',
#   'bar',
#   'sector',
#   'industry',
#   'high-paying',
#   'jobs',
#   'department',
#   'labor',
#   'estimates',
#   'industry',
#   'sector',
#   'lowest',
#   'average',
#   'wages',
#   'lowest',
#   'proportion',
#   'workforce',
#   'earning',
#   'minimum',
#   'subminimum',
#   'wage',
#   'jobs'],
#  ['scott', 'walker', 'bought', 'brand-new', 'vehicles'],
#  ['passed',
#   'measures',
#   'including',
#   'prevent',
#   'groping',
#   'airport',
#   'security',
#   'checks',
#   'bar',
#   'sanctuary',
#   'cities',
#   'texas'],
#  ['average', 'federal', 'worker', 'average', 'private', 'sector', 'worker'],
#  ['political',
#   'appointees',
#   'ipab',
#   'major',
#   'health',
#   'care',
#   'decisions',
#   'americans'],
#  ['stores', 'barred', 'selling', 'watt', 'light', 'bulbs'],
#  ['presidents', 'presidents', 'row', 'consecutively', 're-elected'],
#  ['jason',
#   'carter',
#   'supports',
#   'georgia',
#   'tax',
#   'dollars',
#   'promote',
#   'obamacare'],
#  ['press',
#   'poll',
#   'nader-gonzalez',
#   'percent',
#   'national',
#   'coverage',
#   'mccain',
#   'obama'],
#  ['dan', 'patrick', 'women', 'paid', 'job'],
#  ['average', 'soldiers', 'committing', 'suicide', 'day'],
#  ['republican',
#   'congressmen',
#   'money',
#   'additional',
#   'border',
#   'patrol',
#   'agents'],
#  ['time',
#   'master',
#   'locks',
#   'unionized',
#   'plant',
#   'milwaukee',
#   'running',
#   'capacity'],
#  ['tom', 'reed', 'voted', 'single', 'trade', 'deal', 'form'],
#  ['isis', 'camp', 'miles', 'texas', 'mexican', 'authorities', 'confirm'],
#  ['federal',
#   'projections',
#   'estimate',
#   'health',
#   'care',
#   'overhaul',
#   'cost',
#   'democrats',
#   'originally',
#   'claimed'],
#  ['jersey',
#   'reps',
#   'donald',
#   'payne',
#   'frank',
#   'pallone',
#   'socialists',
#   'openly',
#   'serving',
#   'congress'],
#  ['unemployment', 'rate', 'percent'],
#  ['common', 'core', 'federal', 'government', 'fingerprints'],
#  ['social', 'security', 'ponzi', 'scheme'],
#  ['scott',
#   'walker',
#   'brags',
#   'lot',
#   'independent',
#   'agency',
#   'investigate',
#   'police',
#   'shootings',
#   'fund'],
#  ['arizona', 'law', 'crime', 'federal', 'crime'],
#  ['country',
#   'founded',
#   'congress',
#   'attitude',
#   'sanctity',
#   'christmas',
#   'celebrations',
#   'yeah'],
#  ['miami-dade', 'county', 'spend', 'school', 'educating', 'immigrants'],
#  ['omnibus', 'earmarks'],
#  ['trump',
#   'proposed',
#   'enacting',
#   'largest',
#   'tax',
#   'increase',
#   'american',
#   'history'],
#  ['senator',
#   'mccain',
#   'talking',
#   'tough',
#   'earmarks',
#   'earmarks',
#   'account',
#   'budget'],
#  ['kim',
#   'myers',
#   'voted',
#   'repeatedly',
#   'raise',
#   'taxes',
#   'people',
#   'broome',
#   'county',
#   'millions',
#   'tax',
#   'savings',
#   'family',
#   'business',
#   'relocated',
#   'headquarters'],
#  ['californias',
#   'prop',
#   'requirecondom',
#   'usein',
#   'adult',
#   'films',
#   'workers',
#   'adult',
#   'film',
#   'industry',
#   'riskfor',
#   'lawsuits',
#   'harassment'],
#  ['pay', 'tolls', 'nation', 'privilege', 'crossing', 'bridge'],
#  ['sens',
#   'isaksons',
#   'chambliss',
#   'votes',
#   'unemployment',
#   'insurance',
#   'votes',
#   'kill',
#   'georgia',
#   'jobs'],
#  ['real', 'estate', 'taxes', 'pay', 'obamacare'],
#  ['unemployment', 'running', 'percent', 'legislature'],
#  ['kay', 'bailey', 'hutchison', 'voted', 'sanctuary', 'cities'],
#  ['john', 'mica', 'voted', 'borrow'],
#  ['opponent',
#   'mary',
#   'burke',
#   'told',
#   'reporters',
#   'required',
#   'workers',
#   'bargained-for',
#   'healthcare',
#   'retirement',
#   'benefits',
#   'walker'],
#  ['mccain', 'hired', 'biggest', 'lobbyists', 'washington', 'campaign'],
#  ['raise', 'anybodys', 'tax', 'rates', 'table'],
#  ['terrorists',
#   'killed',
#   'americans',
#   'lebanon',
#   'ronald',
#   'reagan',
#   'democrats',
#   'partisan',
#   'issue'],
#  ['time',
#   'party',
#   'picked',
#   'multiple',
#   'seats',
#   'regular',
#   'election',
#   'mid',
#   'largest',
#   'majority',
#   'party'],
#  ['john', 'raging', 'populist', 'president'],
#  ['house',
#   'republicans',
#   'complained',
#   'time',
#   'constitutional',
#   'ban',
#   'oil',
#   'drilling',
#   'shoved',
#   'proposal',
#   'days',
#   'waters',
#   'oil',
#   'drilling'],
#  ['bush',
#   'family',
#   'attended',
#   'republican',
#   'national',
#   'convention',
#   'president',
#   'bush',
#   'convention'],
#  ['crime', 'rising'],
#  ['flint',
#   'mich',
#   'paying',
#   'times',
#   'poison',
#   'water',
#   'paying',
#   'burlington',
#   'vt',
#   'clean',
#   'water'],
#  ['personal',
#   'tax',
#   'complicated',
#   'costs',
#   'americans',
#   'comply',
#   'current',
#   'tax',
#   'code'],
#  ['portland',
#   'school',
#   'muslim',
#   'students',
#   'school',
#   'prayer',
#   'prayer',
#   'rugs',
#   'class',
#   'times',
#   'day',
#   'pray',
#   'allah'],
#  ['texas',
#   'republicans',
#   'abolishing',
#   'social',
#   'security',
#   'abolishing',
#   'health',
#   'care'],
#  ['bulk', 'people', 'shot', 'weapon', 'drug', 'gangs', 'shot', 'weapon'],
#  ['motors',
#   'bush',
#   'administration',
#   'wrote',
#   'check',
#   'conditions',
#   'change'],
#  ['salaries',
#   'uri',
#   'faculty',
#   'england',
#   'land',
#   'grant',
#   'universities',
#   'lowest',
#   'percent',
#   'major',
#   'institutions'],
#  ['miami',
#   'congressman',
#   'carlos',
#   'curbelo',
#   'supports',
#   'drilling',
#   'offshore',
#   'repeatedly',
#   'voted',
#   'president',
#   'obamas',
#   'ability',
#   'fight',
#   'pollution',
#   'combat',
#   'climate',
#   'change'],
#  ['president',
#   'candidate',
#   'obama',
#   'disclose',
#   'donors',
#   'suspicion',
#   'foreign',
#   'source',
#   'money',
#   'campaign',
#   'refused'],
#  ['oregon',
#   'usa',
#   'continues',
#   'pay',
#   'medical',
#   'benefits',
#   'employees',
#   'families'],
#  ['rand',
#   'paul',
#   'shopping',
#   'billionaire',
#   'billionaire',
#   'fund',
#   'super',
#   'pac'],
#  ['donald',
#   'trump',
#   'cashed',
#   'sept',
#   'collecting',
#   'federal',
#   'funds',
#   'intended',
#   'businesses',
#   'recover',
#   'days',
#   'attack',
#   'trump',
#   'properties'],
#  ['newly',
#   'elected',
#   'president',
#   'obama',
#   'told',
#   'america',
#   'congress',
#   'approved',
#   'plan',
#   'borrow',
#   'dollars',
#   'hold',
#   'unemployment',
#   'percent'],
#  ['independent',
#   'payment',
#   'advisory',
#   'board',
#   'created',
#   'health',
#   'care',
#   'reform',
#   'law',
#   'medicare',
#   'irs',
#   'power',
#   'cut',
#   'medicare',
#   'pay',
#   'government',
#   'programs'],
#  ['mitchell', 'park', 'domes', 'lose', 'million-plus', 'people', 'domes'],
#  ['legislature', 'court', 'employee'],
#  ['evidence',
#   'red',
#   'light',
#   'cameras',
#   'jersey',
#   'reduced',
#   'severity',
#   'accidents',
#   'intersections'],
#  ['entire',
#   'public',
#   'school',
#   'camden',
#   'students',
#   'graduated',
#   'college',
#   'ready'],
#  ['oregonians', 'percent', 'homeowners', 'days', 'delinquent', 'mortgage'],
#  ['hate',
#   'crimes',
#   'pastor',
#   'preacher',
#   'priest',
#   'rabbi',
#   'imam',
#   'sermon',
#   'moral',
#   'traditions',
#   'sexual',
#   'practices',
#   'guilty',
#   'federal',
#   'crime'],
#  ['president', 'obama', 'jobless', 'rate', 'passed', 'stimulus', 'percent'],
#  ['george',
#   'allen',
#   'colleagues',
#   'senate',
#   'biggest',
#   'surplus',
#   'history',
#   'united',
#   'biggest',
#   'deficit',
#   'history',
#   'united'],
#  ['president',
#   'obama',
#   'cracked',
#   'employers',
#   'attracting',
# ...
#  ['trump',
#   'shirts',
#   'bangladesh',
#   'trump',
#   'suits',
#   'mexico',
#   'trump',
#   'vodka',
#   'netherlands',
#   'trump',
#   'crystal',
#   'barware',
#   'slovenia',
#   'cufflinks',
#   'ties',
#   'china'],
#  ['president', 'barack', 'obama', 'trade', 'relationships', 'nations'],
#  ['taxpayer',
#   'subsidy',
#   'oregon',
#   'convention',
#   'center',
#   'hotel',
#   'jumped',
#   'closed-door',
#   'sessions'],
#  ['light',
#   'bulbs',
#   'walmart',
#   'single',
#   'compact',
#   'fluorescent',
#   'lamp',
#   'cfl',
#   'costs',
#   'pop'],
#  ['jeb', 'bush', 'florida', 'decided', 'private', 'emails', 'disclose'],
#  ['history', 'tells', 'job', 'growth', 'lags', 'economic', 'growth'],
#  ['howell',
#   'consistent',
#   'force',
#   'major',
#   'tax',
#   'increase',
#   'virginia',
#   'decade'],
#  ['rhode',
#   'island',
#   'voters',
#   'moderate',
#   'party',
#   'master',
#   'lever',
#   'mechanism',
#   'single',
#   'moderate',
#   'ballot'],
#  ['president',
#   'obama',
#   'attacking',
#   'paul',
#   'ryan',
#   'medicare',
#   'administration',
#   'jim',
#   'langevin',
#   'cut',
#   'medicare'],
#  ['hillary',
#   'clinton',
#   'deleted',
#   'record',
#   'total',
#   'support',
#   'trans-pacific',
#   'partnership',
#   'trade',
#   'agreement',
#   'book'],
#  ['obama', 'iran', 'tiny', 'country', 'pose', 'threat'],
#  ['barbara',
#   'boxers',
#   'worried',
#   'weather',
#   'terrorism',
#   'biggest',
#   'threat',
#   'national',
#   'security'],
#  ['spend', 'times', 'entitlements', 'debt', 'services', 'defense'],
#  ['elections', 'american', 'people', 'overwhelmingly', 'obamacare', 'amnesty'],
#  ['dan',
#   'patrick',
#   'caught',
#   'paying',
#   'taxes',
#   'pocketed',
#   'employees',
#   'payroll',
#   'taxes'],
#  ['merrick',
#   'garland',
#   'authored',
#   'opinion',
#   'release',
#   'guantanamo',
#   'bay',
#   'prisoners',
#   'violent',
#   'islamist',
#   'extremists',
#   'department',
#   'designated',
#   'terrorists'],
#  ['congress',
#   'percent',
#   'approval',
#   'ratings',
#   'percent',
#   'incumbent',
#   'lawmakers',
#   're-elected'],
#  ['letting', 'bush', 'tax', 'cuts', 'expire', 'raise', 'taxes', 'businesses'],
#  ['statistics',
#   'bear',
#   'time',
#   'country',
#   'restrictive',
#   'abortion',
#   'laws',
#   'fatalities',
#   'abortions',
#   'increase'],
#  ['presidents',
#   'budget',
#   'non-defense',
#   'spending',
#   'lowest',
#   'level',
#   'percentage',
#   'economy',
#   'jfk'],
#  ['disenfranchised', 'felons', 'united', 'one-quarter', 'floridians'],
#  ['obama', 'basically', 'threatened', 'bomb', 'pakistan'],
#  ['governor', 'consult', 'party', 'released', 'transportation', 'plan'],
#  ['ohio', 'lost', 'population', 'country'],
#  ['california',
#   'donald',
#   'trump',
#   'jerry',
#   'brown',
#   'gavin',
#   'newsom',
#   'kamala',
#   'harris'],
#  ['rick', 'perry', 'overseen', 'texas', 'unemployment'],
#  ['support', 'auto', 'bailouts'],
#  ['gillespies',
#   'book',
#   'promoted',
#   'individual',
#   'health',
#   'care',
#   'mandate',
#   'recommends',
#   'enforced',
#   'irs',
#   'income',
#   'tax',
#   'code'],
#  ['republican',
#   'extremists',
#   'abortion',
#   'rights',
#   'blake',
#   'rocap',
#   'stopped'],
#  ['obama', 'refuses', 'recognize', 'jerusalem', 'capital', 'israel'],
#  ['helped', 'draft', 'dodd-frank', 'wall', 'street', 'reform'],
#  ['income', 'tax', 'rates', 'eisenhower', 'percent'],
#  ['american', 'homeownership', 'rate', 'lowest', 'rate', 'yrs'],
#  ['romneys', 'medicare', 'plan', 'estimated', 'cost', 'average', 'senior'],
#  ['staffing',
#   'ratio',
#   'officers',
#   'residents',
#   'seattle',
#   'officers',
#   'department'],
#  ['department',
#   'veterans',
#   'affairs',
#   'doctors',
#   'prohibited',
#   'recommending',
#   'medical',
#   'marijuana'],
#  ['career',
#   'politician',
#   'daniel',
#   'webster',
#   'speaker',
#   'house',
#   'wasted',
#   'money',
#   'spiral',
#   'staircase',
#   'office'],
#  ['texas', 'level', 'turnout', 'primary'],
#  ['difference', 'barack', 'obama', 'experience'],
#  ['veterans', 'lives', 'day'],
#  ['united',
#   'major',
#   'country',
#   'earth',
#   'guarantee',
#   'health',
#   'care',
#   'people',
#   'privilege'],
#  ['ambassador',
#   'kenya',
#   'scott',
#   'gration',
#   'forced',
#   'resign',
#   'personal',
#   'emails'],
#  ['florida', 'model', 'successful', 'pretrial', 'release', 'programs'],
#  ['visited',
#   'nashville',
#   'washington',
#   'names',
#   'initials',
#   'carved',
#   'desks'],
#  ['redistribution', 'characteristic', 'america'],
#  ['tampa', 'strip', 'club', 'capital'],
#  ['reached', 'power-sharing', 'agreement', 'republican', 'casey', 'cagle'],
#  ['bicycles', 'parked', 'space', 'required', 'car'],
#  ['unsealed', 'records', 'marquette', 'university'],
#  ['rep', 'allen', 'west', 'constituent'],
#  ['foreign', 'aid', 'cuba', 'venezuela', 'countries', 'enemies'],
#  ['texas', 'wildfires', 'linked', 'climate', 'change'],
#  ['agreement',
#   'millions',
#   'mexican',
#   'citizens',
#   'eligible',
#   'social',
#   'security',
#   'benefits',
#   'stronger',
#   'claim',
#   'benefits',
#   'protection',
#   'cuts',
#   'citizens'],
#  ['earlier',
#   'john',
#   'depetro',
#   'accused',
#   'sexually',
#   'assaulting',
#   'female',
#   'co-worker'],
#  ['photo',
#   'tea',
#   'party',
#   'protests',
#   'crowd',
#   'sprawling',
#   'capitol',
#   'washington',
#   'monument'],
#  ['approval', 'united', 'hillary', 'clinton', 'left', 'secretary', 'office'],
#  ['supervisors',
#   'elections',
#   'florida',
#   'refused',
#   'carry',
#   'effort',
#   'remove',
#   'noncitizens',
#   'voter',
#   'rolls'],
#  ['richardson',
#   'major',
#   'democratic',
#   'candidate',
#   'plan',
#   'withdraw',
#   'american',
#   'troops',
#   'iraq',
#   'major',
#   'democratic',
#   'candidates',
#   'support',
#   'leaving',
#   'american',
#   'troops',
#   'iraq',
#   'indefinitely'],
#  ['earned', 'votes', 'wisconsin', 'donald', 'trump', 'york'],
#  ['republicans',
#   'congress',
#   'eric',
#   'cantors',
#   'defeat',
#   'christian',
#   'white',
#   'black',
#   'senator',
#   'appointed'],
#  ['stamp',
#   'farm',
#   'wind',
#   'turbine',
#   'built',
#   'health',
#   'risk',
#   'flicker',
#   'impact',
#   'created',
#   'shadows',
#   'blades',
#   'turbines',
#   'poses',
#   'real',
#   'health',
#   'risks',
#   'seizures'],
#  ["crist's", 'veto', 'clears', 'taxpayer', 'funding', 'abortion', 'florida'],
#  ['condemned', 'violence', 'campaign', 'arizona', 'march'],
#  ['report', 'wisconsins', 'school', 'graduation', 'rates', 'country'],
#  ['iran',
#   'extremists',
#   'hijacked',
#   'broad-based',
#   'popular',
#   'revolution',
#   'shah',
#   'established',
#   'brutal',
#   'theocracy'],
#  ['immigration', 'reform', 'marco', 'rubio', 'border', 'security', 'spanish'],
#  ['dem-controlled',
#   'ohio',
#   'house',
#   'voted',
#   'change',
#   'process',
#   'create',
#   'objective',
#   'criteria',
#   'modify',
#   'constitution',
#   'politics',
#   'efforts',
#   'draw',
#   'legislative',
#   'boundaries'],
#  ['people', 'advanced', 'economies', 'combined'],
#  ['obama',
#   'voted',
#   'critical',
#   'resources',
#   'individual',
#   'body',
#   'armor',
#   'helicopters',
#   'ammunition',
#   'aircraft'],
#  ['sen', 'sherrod', 'brown', 'responsible', 'debt'],
#  ['tom',
#   'barretts',
#   'leadership',
#   'violent',
#   'crime',
#   'milwaukee',
#   'decreased',
#   'lowest',
#   'levels'],
#  ['barack', 'obama', 'appeared', 'video', 'whoomp'],
#  ['florida', 'concealed', 'weapon', 'permits', 'nation', 'double', 'texas'],
#  ['president',
#   'george',
#   'bush',
#   'months',
#   'uninterrupted',
#   'job',
#   'creation',
#   'revenues',
#   'all-time'],
#  ['scott',
#   'walker',
#   'balance',
#   'budget',
#   'larger',
#   'deficit',
#   'months',
#   'term',
#   'elected'],
#  ['compared',
#   'direct',
#   'sales',
#   'manufacturers',
#   'consumers',
#   'save',
#   'avg',
#   'car',
#   'sold',
#   'franchised',
#   'dealer',
#   'model'],
#  ['josh',
#   'mandel',
#   'voted',
#   'insurance',
#   'companies',
#   'deny',
#   'coverage',
#   'autism'],
#  ['prior',
#   'obamacare',
#   'wisconsin',
#   'percent',
#   'wisconsinites',
#   'covered',
#   'insurance',
#   'obamacare',
#   'percent',
#   'wisconsinites',
#   'covered',
#   'insurance',
#   'impact'],
#  ['secretary',
#   'clinton',
#   'position',
#   'gun',
#   'issues',
#   'election',
#   'position',
#   'campaigning',
#   'president',
#   'obama',
#   'federal',
#   'standards'],
#  ['rifle', 'omar', 'mateen', 'shoots', 'rounds', 'minute'],
#  ['building',
#   'running',
#   'atlanta',
#   'streetcar',
#   'projected',
#   'create',
#   'jobs'],
#  ['wisconsin', 'bluest', 'scott', 'walker', 'unemployment', 'rate'],
#  ['residential',
#   'property',
#   'taxes',
#   'providence',
#   'percent',
#   'mayor',
#   'taveras'],
#  ['assault',
#   'weapons',
#   'handguns',
#   'allowed',
#   'capitol',
#   'bullhorns',
#   'trumpets',
#   'helium',
#   'balloons',
#   'flags',
#   'poles',
#   'banned'],
#  ['teachers', 'consecutive', 'salary', 'increases'],
#  ['paid', 'employee', 'rhode', 'island', 'basketball', 'coach'],
#  ['lobbyists', 'running', 'campaign'],
#  ['expanding',
#   'medicaid',
#   'require',
#   'borrowing',
#   'money',
#   'drastically',
#   'expanding',
#   'deficit'],
#  ['jeb',
#   'bushs',
#   'terms',
#   'office',
#   'floridas',
#   'graduation',
#   'rate',
#   'dead',
#   'remains'],
#  ['farming', 'fastest', 'growing', 'economy'],
#  ['increase', 'alcohol', 'underage', 'kids', 'alcohol', 'illegal', 'kids'],
#  ['obamacare', 'bureaucrat', 'cat', 'scan', 'delayed', 'treatment'],
#  ['proposed', 'keystone', 'xl', 'oil', 'pipeline', 'bipartisan', 'proposal'],
#  ['support', 'gay', 'marriage'],
#  ['mitt', 'romney', 'speech', 'weeks', 'troops', 'iraq'],
#  ['david',
#   'dewhurst',
#   'explicitly',
#   'advocated',
#   'guest',
#   'worker',
#   'program',
#   'illegal',
#   'immigrants'],
#  ['republican',
#   'proposal',
#   'medicare',
#   'age',
#   'participate',
#   'health',
#   'plan',
#   'congress'],
#  ['affordable',
#   'care',
#   'federal',
#   'takeover',
#   'student',
#   'loan',
#   'industry',
#   'profits',
#   'loans',
#   'pay',
#   'health',
#   'care',
#   'law'],
#  ['barack', 'obama', 'days', 'senate', 'vote'],
#  ['percentof', 'parents', 'spankers'],
#  ['wisconsin', 'taxed', 'nation'],
#  ['opponent',
#   'flores',
#   'helped',
#   'company',
#   'laid',
#   'workers',
#   'paid',
#   'executives',
#   'millions'],
#  ['michelle', 'obama', 'people', 'staff', 'nancy', 'reagan'],
#  ['rick', 'perry', 'doubled', 'spending', 'decade'],
#  ['texas',
#   'owns',
#   'public',
#   'lands',
#   'federal',
#   'govt',
#   'create',
#   'park',
#   'permission'],
#  ['decision',
#   'week',
#   'time',
#   'supreme',
#   'court',
#   'voted',
#   'president',
#   'exceeded',
#   'constitutional',
#   'authority'],
#  ['tammy',
#   'baldwin',
#   'supports',
#   'law',
#   'government',
#   'decisions',
#   'medicine',
#   'doctors',
#   'hospitals'],
#  ['projected',
#   'budget',
#   'shortfall',
#   'assumption',
#   'based',
#   'growth',
#   'happen'],
#  ['continue',
#   'obamacare',
#   'siphon',
#   'dollars',
#   'medicare',
#   'accounts',
#   'falls',
#   'seams'],
#  ['sen',
#   'john',
#   'mccain',
#   'spent',
#   'july',
#   'weekend',
#   'islamabad',
#   'pakistan',
#   'selling',
#   'advanced',
#   'weapons',
#   'folks',
#   'harbored',
#   'osama',
#   'bin',
#   'laden'],
#  ['donald', 'trump', 'america'],
#  ['president',
#   'obama',
#   'unnecessarily',
#   'delaying',
#   'flight',
#   'faa',
#   'cut',
#   'spending'],
#  ['john',
#   'cornyn',
#   'voted',
#   'increase',
#   'debt',
#   'raise',
#   'taxes',
#   'bail',
#   'wall',
#   'street',
#   'banks',
#   'fund',
#   'obamacare'],
#  ['washington', 'politicians', 'social', 'security', 'ponzi', 'scheme'],
#  ['republican',
#   'presidential',
#   'candidate',
#   'john',
#   'kasich',
#   'spent',
#   'days',
#   'taxpayer',
#   'money',
#   'costly',
#   'campaign'],
#  ['obamas', 'attended', 'school', 'friend', 'person'],
#  ['california', 'sixth', 'largest', 'economy', 'planet', 'earth'],
#  ['barack', "obama's", 'plan', 'calls', 'mandates', 'fines', 'businesses'],
#  ['proposed',
#   'northern',
#   'wisconsin',
#   'iron',
#   'ore',
#   'hours',
#   'public',
#   'hearing',
#   'mining',
#   'held'],
#  ['credit', 'rating', 'office'],
#  ['african-american', 'children', 'percent', 'die', 'asthma', 'white', 'kids'],
#  ['police', 'killed', 'people', 'month', 'century'],
#  ['legislature', 'opportunity', 'debate', 'vote', 'loaning', 'studios'],
#  ['ceos', 'minutes', 'ordinary', 'workers', 'wrong'],
#  ['soccer', 'players', 'mens', 'national', 'team', 'immigrants'],
#  ['president',
#   'executive',
#   'grant',
#   'voting',
#   'rights',
#   'illegal',
#   'immigrants',
#   'newly',
#   'legalized',
#   'pending',
#   'legislation'],
#  ['rob', 'portman', 'fewest', 'votes', 'ohio', 'senate', 'victors'],
#  ['senate',
#   'candidate',
#   'michelle',
#   'nunn',
#   'handpicked',
#   'president',
#   'barack',
#   'obama'],
#  ['china', 'owns', 'percent', 'debt'],
#  ['chris',
#   'sununu',
#   'supported',
#   'obamas',
#   'common',
#   'core',
#   'agenda',
#   'local',
#   'control',
#   'schools'],
#  ['president',
#   'barack',
#   'obama',
#   'unemployment',
#   'gonna',
#   'percent',
#   'passed',
#   'stimulus',
#   'plan'],
#  ['gwinnett', 'county', 'government', 'cutbacks', 'staffing'],
#  ['constitution',
#   'congress',
#   'write',
#   'legislation',
#   'immigration',
#   'policy',
#   'barack',
#   'obama',
#   'lacks',
#   'authority',
#   'defer',
#   'deportation',
#   'illegal',
#   'immigrants'],
#  ['crime', 'rises', 'communities', 'casinos'],
#  ['americans',
#   'spend',
#   'hours',
#   'complying',
#   'tax',
#   'law',
#   'costs',
#   'comply',
#   'tax',
#   'laws',
#   'annually'],
#  ['space',
#   'shuttle',
#   'national',
#   'museum',
#   'united',
#   'air',
#   'force',
#   'dayton',
#   'days',
#   'drive',
#   'percent',
#   'population'],
#  ['cutting',
#   'budget',
#   'congressdecision',
#   'sequestration',
#   'secretary',
#   'defense',
#   'president'],
#  ['arizona', 'schools', 'rank', 'nation', 'dead', 'funding', 'student'],
#  ['rhode', 'island', 'country', 'alcohol-related', 'fatalities'],
#  ['maj',
#   'nidal',
#   'hasan',
#   'accused',
#   'fort',
#   'hood',
#   'shootings',
#   'advisor',
#   'obama',
#   'administration'],
#  ['florida',
#   'second-lowest',
#   'campaign',
#   'contribution',
#   'limit',
#   'entire',
#   'country'],
#  ['ceo',
#   'wwe',
#   'linda',
#   'mcmahon',
#   'caught',
#   'tipping',
#   'ringside',
#   'physician',
#   'federal',
#   'investigation',
#   'illegally',
#   'distributing',
#   'steroids',
#   'wrestlers'],
#  ['hezbollah',
#   'latin',
#   'america',
#   'venezuela',
#   'mexico',
#   'latin',
#   'america',
#   'poses',
#   'imminent',
#   'threat',
#   'united',
#   'america'],
#  ['millionaires', 'food', 'stamps', 'unemployment', 'save'],
#  ['polls',
#   'including',
#   "week's",
#   'time',
#   'magazine',
#   'beat',
#   'john',
#   'mccain'],
#  ['david',
#   'beckhams',
#   'proposed',
#   'soccer',
#   'stadium',
#   'miamis',
#   'port',
#   'threatens',
#   'jobs',
#   'economic',
#   'impact',
#   'tied',
#   'cargo',
#   'cruise',
#   'industries'],
#  ['pass', 'immigration', 'reform', 'wages', 'average', 'average', 'household'],
#  ['president',
#   'clinton',
#   'raised',
#   'tax',
#   'rates',
#   'levels',
#   'proposed',
#   'obama',
#   'country',
#   'experienced',
#   'job',
#   'growth'],
#  ['scott',
#   'walker',
#   'wisconsin',
#   'job',
#   'creation',
#   'money',
#   'cronies',
#   'corporate',
#   'friends',
#   'contributed',
#   'campaigns',
#   'job-development',
#   'incentives'],
#  ['actions',
#   'president',
#   'barack',
#   'obama',
#   'burger',
#   'king',
#   'national',
#   'headquarters',
#   'announced',
#   'month',
#   'pulling',
#   'franchises',
#   'military',
#   'bases'],
#  ['scott', 'walker', 'plan', 'privatize', 'lands', 'sell', 'deer', 'bidder'],
#  ['united',
#   'allies',
#   'lined',
#   'air',
#   'strikes',
#   'syria',
#   'obama',
#   'pulled',
#   'rug'],
#  ['president',
#   'united',
#   'engage',
#   'american',
#   'troops',
#   'fourth',
#   'conflict',
#   'foreign',
#   'land',
#   'historic'],
#  ['signed', 'pledge', 'raise', 'taxes', 'times'],
#  ['unemployment', 'texas', 'risen', 'percentage', 'rick', 'perry', 'governor'],
#  ['reps',
#   'paul',
#   'ryan',
#   'sean',
#   'duffy',
#   'reid',
#   'ribble',
#   'shutting',
#   'town',
#   'hall',
#   'meetings',
#   'constituents',
#   'pay',
#   'attend'],
#  ['rick',
#   'perry',
#   'injecting',
#   'year-old',
#   'girls',
#   'controversial',
#   'drug',
#   'hpv',
#   'vaccine',
#   'parents',
#   'consent',
#   'idea'],
#  ['gay', 'pride', 'vote', 'discrimination'],
#  ['republicans',
#   'privatize',
#   'social',
#   'security',
#   'idea',
#   'social',
#   'security',
#   'trust',
#   'fund',
#   'wall',
#   'street'],
#  ['night',
#   'iowa',
#   'caucuses',
#   'obama',
#   'promised',
#   'nation',
#   'health',
#   'care',
#   'reform',
#   'focused',
#   'cost',
#   'containment',
#   'opposed',
#   'individual',
#   'mandate',
#   'republicans'],
#  ['florida', 'rubber-stamped', 'phony', 'horse', 'racing'],
#  ['key',
#   'leonard',
#   'lance',
#   'project',
#   'vote',
#   'smart',
#   'guns',
#   'carry',
#   'concealed',
#   'weapons',
#   'national',
#   'parks'],
#  ...]

# %%
# Remove words that are only shown once
def removeWordsWithOneAppearance(statement_data):
    words = list(chain.from_iterable(statement_data))
    
    words_frequency = FreqDist(words)
    
    one_appearance = [word for word in words if words_frequency[word] == 1]
    
    statement_data = [[token for token in sublist if word not in one_appearance] for sublist in statement_data]
    
    return statement_data

# %%
tokenized_df_statement_data = removeWordsWithOneAppearance(tokenized_df_statement_data)

# %%
# Add the tokens to their respective datasets
df['Statement'] = tokenized_df_statement_data

# %%
df['Statement'] = df['Statement'].apply(lambda x: ' '.join(x))

# %%
# Change labels to binary for model training

def changeLabels(statement_data):
    statement_data['Label'] = statement_data['Label'].apply(lambda x: 1 
                                                            if x == 'true' or x == 'mostly-true' 
                                                            or x == 'half-true' else 0)
    return statement_data

# %%
df = changeLabels(df)

# %%
df.head()
# Out:
#            ID  Label                                          Statement  \
# 0   2635.json      0  annies list political supports third-trimester...
# 1  10540.json      1  decline coal start started natural gas started...
# 2    324.json      1  hillary clinton agrees john mccain voting geor...
# 3   1123.json      0  health care reform legislation mandate sex cha...
# 4   9028.json      1                   economic turnaround started term
#
#                               Subject         Speaker                 Title  \
# 0                            abortion    dwayne-bohac  state representative
# 1  energy,history,job-accomplishments  scott-surovell        state delegate
# 2                      foreign-policy    barack-obama             president
# 3                         health-care    blog-posting                   NaN
# 4                        economy,jobs   charlie-crist                   NaN
#
#       State       Party  True Counts  Flase Counts  Half True Counts  \
# 0     texas  republican          0.0           1.0               0.0
# 1  virginia    democrat          0.0           0.0               1.0
# 2  illinois    democrat         70.0          71.0             160.0
# 3       NaN        none          7.0          19.0               3.0
# 4   florida    democrat         15.0           9.0              20.0
#
#    Mostly True Counts  Pants On Fire Counts              Context
# 0                 0.0                   0.0             a mailer
# 1                 1.0                   0.0      a floor speech.
# 2               163.0                   9.0               denver
# 3                 5.0                  44.0       a news release
# 4                19.0                   2.0  an interview on cnn

# %%
statement_with_any_null = df[df['Statement'].isnull()]

# %%
statement_with_any_null
# Out:
# Empty DataFrame
# Columns: [ID, Label, Statement, Subject, Speaker, Title, State, Party, True Counts, Flase Counts, Half True Counts, Mostly True Counts, Pants On Fire Counts, Context]
# Index: []

# %%
df.to_excel("tokenized_training_data.xlsx")
