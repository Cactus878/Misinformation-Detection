# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
KNN_preds = np.loadtxt("prediction_results/KNN_pred_results.txt", dtype=str, skiprows=1)
KNN_combined_preds = np.loadtxt("prediction_results/KNN_combined_pred_results.txt", dtype=str, skiprows=1)

y_KNN_test = KNN_preds[:, 0]
y_KNN_pred = KNN_preds[:, 1]

y_combined_KNN_test = KNN_combined_preds[:, 0]
y_combined_KNN_preds = KNN_combined_preds[:, 1]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 KNN_preds = np.loadtxt("prediction_results/KNN_pred_results.txt", dtype=str, skiprows=1)
# ----> 2 KNN_combined_preds = np.loadtxt("prediction_results/KNN_combined_pred_results.txt", dtype=str, skiprows=1)
#       4 y_KNN_test = KNN_preds[:, 0]
#       5 y_KNN_pred = KNN_preds[:, 1]
#
# File ~\New folder\Lib\site-packages\numpy\lib\npyio.py:1373, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1370 if isinstance(delimiter, bytes):
#    1371     delimiter = delimiter.decode('latin1')
# -> 1373 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1374             converters=converters, skiplines=skiprows, usecols=usecols,
#    1375             unpack=unpack, ndmin=ndmin, encoding=encoding,
# ...

# %%
accuracy = accuracy_score(y_KNN_test, y_KNN_pred)
conf_matrix = confusion_matrix(y_KNN_test, y_KNN_pred)

print(f'Accuracy: {accuracy}')
sns.heatmap(conf_matrix, annot=True, fmt='d')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %%
accuracy = accuracy_score(y_combined_KNN_test, y_combined_KNN_preds)
conf_matrix = confusion_matrix(y_combined_KNN_test, y_combined_KNN_preds)

print(f'Accuracy: {accuracy}')
sns.heatmap(conf_matrix, annot=True, fmt='d')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()
# Out:
# Accuracy: 0.59147771696638

# %%
MNB_preds = np.loadtxt("prediction_results/MNB_pred_results.txt", dtype=str, skiprows=1)
MNB_combined_preds = np.loadtxt("prediction_results/MNB_combined_pred_results.txt", dtype=str, skiprows=1)

y_MNB_test = MNB_preds[:, 0]
y_MNB_pred = MNB_preds[:, 1]

y_combined_MNB_test = MNB_combined_preds[:, 0]
y_combined_MNB_preds = MNB_combined_preds[:, 1]

# %%
accuracy = accuracy_score(y_MNB_test, y_MNB_pred)
conf_matrix = confusion_matrix(y_MNB_test, y_MNB_pred)

print(f'Accuracy: {accuracy}')
sns.heatmap(conf_matrix, annot=True, fmt='d')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()
# Out:
# Accuracy: 0.5961688819390148

# %%
accuracy = accuracy_score(y_combined_MNB_test, y_combined_MNB_preds)
conf_matrix = confusion_matrix(y_combined_MNB_test, y_combined_MNB_preds)

print(f'Accuracy: {accuracy}')
sns.heatmap(conf_matrix, annot=True, fmt='d')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()
# Out:
# Accuracy: 0.612587959343237

# %%
RFC_preds = np.loadtxt("prediction_results/RFC_pred_results.txt", dtype=str, skiprows=1)
RFC_combined_preds = np.loadtxt("prediction_results/RFC_combined_pred_results.txt", dtype=str, skiprows=1)

y_RFC_test = RFC_preds[:, 0]
y_RFC_pred = RFC_preds[:, 1]

y_combined_RFC_test = RFC_combined_preds[:, 0]
y_combined_RFC_preds = RFC_combined_preds[:, 1]

# %%
accuracy = accuracy_score(y_RFC_test, y_RFC_pred)
conf_matrix = confusion_matrix(y_RFC_test, y_RFC_pred)

print(f'Accuracy: {accuracy}')
sns.heatmap(conf_matrix, annot=True, fmt='d')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()
# Out:
# Accuracy: 0.5942142298670836

# %%
accuracy = accuracy_score(y_combined_RFC_test, y_combined_RFC_preds)
conf_matrix = confusion_matrix(y_combined_RFC_test, y_combined_RFC_preds)

print(f'Accuracy: {accuracy}')
sns.heatmap(conf_matrix, annot=True, fmt='d')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()
# Out:
# Accuracy: 0.6391712275215011
